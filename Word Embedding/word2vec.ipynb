# %%
import re  # For preprocessing
import pandas as pd  # For data handling
from time import time  # To time our operation
from collections import defaultdict  # For word frequency

import spacy  # For preprocessing

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %%
df = pd.read_csv('game-of-thrones.csv')
df.shape
# Out:
# (33198, 5)

# %%
df.head()
# Out:
#                                                 Text       Speaker  \
# 0  [First scene opens with three Rangers riding t...           NaN
# 1   What d’you expect? They’re savages. One lot s...  WAYMAR ROYCE
# 2   I’ve never seen wildlings do a thing like thi...          WILL
# 3                             How close did you get?  WAYMAR ROYCE
# 4                            Close as any man would.          WILL
#
#                Episode     Season             Show
# 0  e1-Winter is Coming  season-01  Game-of-Thrones
# 1  e1-Winter is Coming  season-01  Game-of-Thrones
# 2  e1-Winter is Coming  season-01  Game-of-Thrones
# 3  e1-Winter is Coming  season-01  Game-of-Thrones
# 4  e1-Winter is Coming  season-01  Game-of-Thrones

# %%
nlp = spacy.load('en_core_web_sm') # disabling Named Entity Recognition for speed

def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    txt = [token.lemma_ for token in doc if not token.is_stop]
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    if len(txt) > 2:
        return ' '.join(txt)

# %%
brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df['Text'])

# %%
t = time()

txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_process=-1)]

print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 0.88 mins

# %%
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (24710, 1)

# %%
from gensim.models.phrases import Phrases, Phraser

# %%
sent = [row.split() for row in df_clean['clean']]

# %%
phrases = Phrases(sent, min_count=5, progress_per=10000)
# Out:
# INFO - 08:04:25: collecting all words and their counts
# INFO - 08:04:25: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 08:04:25: PROGRESS: at sentence #10000, processed 66539 words and 50089 word types
# INFO - 08:04:25: PROGRESS: at sentence #20000, processed 141631 words and 93894 word types
# INFO - 08:04:25: collected 113055 token types (unigram + bigrams) from a corpus of 179101 words and 24710 sentences
# INFO - 08:04:25: merged Phrases<113055 vocab, min_count=5, threshold=10.0, max_vocab_size=40000000>
# INFO - 08:04:25: Phrases lifecycle event {'msg': 'built Phrases<113055 vocab, min_count=5, threshold=10.0, max_vocab_size=40000000> in 0.27s', 'datetime': '2023-03-01T08:04:25.938154', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'created'}

# %%
bigram = Phraser(phrases)
sentences = bigram[sent]
# Out:
# INFO - 08:04:30: exporting phrases from Phrases<113055 vocab, min_count=5, threshold=10.0, max_vocab_size=40000000>
# INFO - 08:04:30: FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<587 phrases, min_count=5, threshold=10.0> from Phrases<113055 vocab, min_count=5, threshold=10.0, max_vocab_size=40000000> in 0.27s', 'datetime': '2023-03-01T08:04:30.392095', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'created'}

# %%
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 9045

# %%
word_freq
# Out:
# defaultdict(int,
#             {'scene': 31,
#              'open': 202,
#              'ranger': 49,
#              'ride': 317,
#              'tunnel': 39,
#              'leave': 673,
#              'wall': 425,
#              'go': 649,
#              'wood': 100,
#              'eerie': 2,
#              'music': 14,
#              'background': 27,
#              'split': 9,
#              'find': 472,
#              'campsite': 3,
#              'mutilated': 1,
#              'body': 177,
#              'include': 24,
#              'child': 342,
#              'hang': 68,
#              'tree': 82,
#              'branch': 7,
#              'bird': 38,
#              'eye': 263,
#              'view': 28,
#              'show': 51,
#              'arrange': 19,
#              'shield': 57,
#              'like': 870,
#              'pattern': 1,
#              'd': 127,
#              'expect': 77,
#              'savage': 28,
#              'lot': 111,
#              'steal': 87,
#              'goat': 24,
#              'know': 1432,
#              'rip': 31,
#              'piece': 63,
#              've_see': 28,
#              'wildling': 187,
#              'thing': 413,
#              'life': 278,
#              'close': 204,
#              'man': 2268,
#              'head': 416,
#              'dead': 390,
#              'frighten': 22,
#              'order': 126,
#              'track': 13,
#              'win_t': 78,
#              'trouble': 42,
#              'don_t': 318,
#              'think': 791,
#              'll': 331,
#              'ask': 264,
#              'die': 478,
#              'horse': 364,
#              'gare': 5,
#              'grumble': 2,
#              'kill': 725,
#              's': 1699,
#              'good': 710,
#              'want': 1157,
#              'run_away': 29,
#              'south': 73,
#              'course': 164,
#              'behead': 27,
#              'deserter': 7,
#              'catch': 88,
#              'glare': 14,
#              'obey': 35,
#              'later': 63,
#              'return': 233,
#              'completely': 15,
#              'clear': 50,
#              'move': 119,
#              'camp': 95,
#              'look': 1610,
#              'sword': 468,
#              'draw': 84,
#              'hear': 481,
#              'wind': 34,
#              'call': 108,
#              'red': 127,
#              'cloth': 14,
#              'snow': 120,
#              'speak': 308,
#              'creature': 17,
#              'glow': 8,
#              'blue_eye': 13,
#              'rise': 114,
#              'royce': 10,
#              'turn': 657,
#              'strike': 80,
#              'scene_shift': 26,
#              'cry': 94,
#              'stampede': 1,
#              'past': 104,
#              'see': 640,
#              'stand': 877,
#              'distance': 85,
#              'figure': 38,
#              'suspend': 3,
#              'run': 295,
#              'flee': 42,
#              'strange': 44,
#              'growl': 36,
#              'glimpse': 4,
#              'terrified': 3,
#              'stop': 387,
#              'apart': 14,
#              'breath': 42,
#              'sink': 14,
#              'knee': 57,
#              'toss': 47,
#              'title': 35,
#              'sequence': 1,
#              'rider': 64,
#              'winterfell': 351,
#              'come': 1140,
#              'daze': 4,
#              'castle': 178,
#              'bran': 372,
#              'practice': 27,
#              'archery': 5,
#              'get': 517,
#              'frustrated': 3,
#              'jon_snow': 303,
#              'robb_stark': 60,
#              'jon': 891,
#              'pats': 9,
#              'shoulder': 96,
#              'father': 778,
#              'watch': 482,
#              'ned': 135,
#              'catelyn_stark': 30,
#              'needlework': 2,
#              'girl': 418,
#              'inside': 153,
#              'fine': 97,
#              'work': 187,
#              'love': 370,
#              'detail': 8,
#              've': 197,
#              'manage': 27,
#              'corner': 25,
#              'beautiful': 74,
#              'stitching': 2,
#              'murmur': 12,
#              'sansa': 648,
#              'embroidery': 3,
#              'arya': 753,
#              'struggle': 43,
#              'listen': 114,
#              'arrow': 121,
#              'hit': 115,
#              'male': 6,
#              'laughter': 11,
#              'outside': 152,
#              'try': 355,
#              'miss': 65,
#              'laugh': 204,
#              'marksman': 1,
#              'relax': 5,
#              'bow': 151,
#              'arm': 160,
#              'pull': 220,
#              'bullseye': 3,
#              'robb': 215,
#              'surprise': 28,
#              'curtsy': 6,
#              'perfect': 22,
#              'shot': 34,
#              'take': 664,
#              'quick': 36,
#              'fast': 41,
#              'rodrick': 7,
#              'cassel': 6,
#              'theon_greyjoy': 27,
#              'approach': 324,
#              'catelyn': 148,
#              'balcony': 43,
#              'lord': 898,
#              'stark': 372,
#              'lady': 379,
#              'guardsman': 2,
#              'hill': 40,
#              'capture': 34,
#              'night': 413,
#              'grimace': 6,
#              'lad': 55,
#              'saddle': 19,
#              'theon': 402,
#              'depart': 14,
#              'swear_oath': 15,
#              'cat': 31,
#              'law': 46,
#              'tell': 768,
#              'nod': 167,
#              'ne': 23,
#              'young': 157,
#              'boy': 460,
#              'forever': 27,
#              'winter_come': 25,
#              'courtyard': 148,
#              'gather': 90,
#              'walk_away': 178,
#              'rest': 155,
#              'block': 46,
#              'white_walker': 86,
#              'face': 419,
#              'break': 131,
#              'oath': 27,
#              'm': 233,
#              'warn': 27,
#              'people': 478,
#              'need': 641,
#              'word': 197,
#              'family': 240,
#              'coward': 32,
#              'm_sorry': 20,
#              'yes': 274,
#              'position': 56,
#              'limb': 9,
#              'serve': 233,
#              'ice': 34,
#              'scabbard': 2,
#              'hold': 383,
#              'forgive': 98,
#              'robert': 99,
#              'house_baratheon': 16,
#              'away': 463,
#              'king_andal': 11,
#              'seven_kingdom': 128,
#              'protector_realm': 20,
#              'eddard': 10,
#              'house_stark': 22,
#              'warden_north': 26,
#              'sentence_die': 7,
#              'swing': 47,
#              'put': 123,
#              'say': 392,
#              'understand': 142,
#              'way': 498,
#              'old': 256,
#              'pass': 117,
#              'sentence': 12,
#              'swing_sword': 16,
#              'true': 176,
#              'thousand_year': 33,
#              'madman': 7,
#              'stag': 23,
#              'bridge': 32,
#              'ravage': 1,
#              'deer': 7,
#              'mountain': 116,
#              'lion': 62,
#              'begin': 350,
#              'search': 25,
#              'direwolf': 38,
#              'antler': 2,
#              'throat': 66,
#              'pup': 7,
#              'whimper': 10,
#              'freak': 2,
#              'glance': 32,
#              'tough': 16,
#              'beast': 44,
#              'direwolve': 9,
#              'south_wall': 19,
#              'pick': 149,
#              'offer': 105,
#              'mother': 362,
#              'belong': 68,
#              'well': 297,
#              'death': 160,
#              'blade': 68,
#              'sigil_house': 8,
#              'mean': 250,
#              'great': 261,
#              'hope': 129,
#              'train': 42,
#              'feed': 71,
#              'bury': 40,
#              'cradle': 13,
#              'hand': 793,
#              'pause': 79,
#              'white': 48,
#              'wolf_pup': 6,
#              'runt': 1,
#              'litter': 7,
#              'bell': 19,
#              'ring': 32,
#              'king_land': 39,
#              'iron_throne': 60,
#              'surround': 67,
#              'druidical': 1,
#              'looking': 1,
#              'celebrant': 1,
#              'lie': 208,
#              'jon_arryn': 24,
#              'cersei': 599,
#              'jaime': 688,
#              'brother': 575,
#              'feel': 116,
#              'duty': 60,
#              'worry': 49,
#              'start': 399,
#              'seven': 61,
#              'jump': 49,
#              'cliff': 31,
#              'casterly_rock': 62,
#              'foot': 161,
#              'drop': 118,
#              'water': 147,
#              'afraid': 108,
#              'whisper': 43,
#              'mimic': 4,
#              'lannister': 377,
#              'lannisters': 1,
#              'act': 43,
#              'fool': 89,
#              'king': 894,
#              'skewer': 5,
#              'city': 251,
#              'gate': 195,
#              'didn_t': 100,
#              'choose': 133,
#              'new': 158,
#              'job': 37,
#              'fucking': 77,
#              'boar': 14,
#              'hunt': 51,
#              'whore': 129,
#              'honor': 156,
#              'day': 401,
#              'long': 376,
#              'short': 39,
#              'raven': 66,
#              'cross': 50,
#              'busy': 27,
#              'godswood': 27,
#              'year': 181,
#              'feel_like': 20,
#              'outsider': 9,
#              'northern': 51,
#              'wonder': 48,
#              'old_god': 22,
#              'agree': 38,
#              'god': 279,
#              'rule': 106,
#              'sorry': 127,
#              'fever': 5,
#              'sister': 239,
#              'health': 8,
#              'bring': 387,
#              'news': 17,
#              'queen': 441,
#              'far': 151,
#              'north': 313,
#              'great_hall': 17,
#              'banquet': 12,
#              'prepare': 48,
#              'plenty': 20,
#              'candle': 28,
#              'tyrion': 919,
#              'chamber': 186,
#              'read': 94,
#              'drink': 252,
#              'possibly': 17,
#              'stature': 2,
#              'barrel': 29,
#              'ale': 24,
#              'cellar': 5,
#              'case': 18,
#              'getting': 11,
#              'barber': 1,
#              'set': 127,
#              'pretty': 73,
#              'bet': 38,
#              'sleek': 2,
#              'mink': 3,
#              'prince': 74,
#              'right': 530,
#              'royal': 48,
#              'prick': 5,
#              'southern': 20,
#              'stab': 82,
#              'tommy': 3,
#              'shave': 11,
#              'meet': 198,
#              'hair': 102,
#              'procession': 4,
#              'perch': 6,
#              'high': 95,
#              'atop': 22,
#              'castle_wall': 21,
#              'clamber': 3,
#              'nimbly': 1,
#              'luwin': 32,
#              'walk': 1033,
#              'grow': 112,
#              'brandon': 11,
#              'hundred': 25,
#              'time': 588,
#              'climbing': 5,
#              'road': 57,
#              'promise': 153,
#              'climb': 89,
#              'follow': 262,
#              'grand': 13,
#              'entry': 5,
#              'wear': 72,
#              'helm': 9,
#              'cloak': 41,
#              'push': 120,
#              'tall': 26,
#              'wagon': 32,
#              'joffrey': 375,
#              'hound': 245,
#              'wait': 202,
#              'greeting': 3,
#              'line': 84,
#              'banner': 38,
#              'scoot': 1,
#              'parent': 8,
#              'receiving': 1,
#              'hey': 18,
#              'smile': 253,
#              'coach': 2,
#              'carry': 180,
#              'lumber': 3,
#              'king_robert': 47,
#              'kneel': 119,
#              'heave': 9,
#              'look_shocked': 10,
#              'sight': 30,
#              'friend': 278,
#              'fat': 42,
#              'signal': 26,
#              've_get': 18,
#              'give': 309,
#              'haven_t': 21,
#              'hell': 21,
#              'guard': 271,
#              'grace': 407,
#              'descend': 19,
#              'imp': 36,
#              'ooh': 7,
#              'muscle': 6,
#              'soldier': 256,
#              'remove': 105,
#              'jaime_lannister': 48,
#              'twin': 42,
#              'crypt': 30,
#              'pay': 131,
#              'respect': 53,
#              'month': 25,
#              'surely': 12,
#              'humiliate': 9,
#              'little': 313,
#              'scene_change': 15,
#              'minute': 10,
#              'burn': 192,
#              'teach': 95,
#              'remember': 198,
#              'crack': 20,
#              'skull': 28,
#              'fuck': 157,
#              'fault': 15,
#              'sighs': 1,
#              'damn': 41,
#              'use': 98,
#              'anybody': 8,
#              'lord_eddard': 19,
#              'worthy': 14,
#              'kingdom': 39,
#              'eat': 145,
#              'early': 26,
#              'grave': 14,
#              'help': 320,
#              'win': 108,
#              'live': 238,
#              'bind': 55,
#              'blood': 205,
#              'late': 41,
#              'son': 383,
#              'daughter': 150,
#              'join': 126,
#              'house': 233,
#              'settlement': 1,
#              'whorehouse': 4,
#              'swill': 3,
#              'liquor': 1,
#              'woman': 357,
#              'pop': 8,
#              'service': 46,
#              'mmh': 1,
#              'handsome': 21,
#              'clever': 35,
#              'hate': 99,
#              'nickname': 3,
#              'oh': 230,
#              'earn': 13,
#              'drunken': 15,
#              'lecher': 2,
#              'manner': 13,
#              'perversion': 5,
#              'blessing': 9,
#              'knock': 103,
#              'explain': 30,
#              'meaning': 4,
#              'closed': 3,
#              'door': 176,
#              'doubt': 31,
#              'crave': 3,
#              'attention': 44,
#              'odd': 27,
#              'craving': 1,
#              'trait': 1,
#              'feast': 31,
#              'sundown': 5,
#              'bit': 142,
#              'open_door': 50,
#              'bevy': 1,
#              'enter': 326,
#              'close_door': 35,
#              'lyanna': 44,
#              'tomb': 5,
#              'place': 317,
#              'feather': 6,
#              'statue': 28,
#              'sun': 29,
#              'cloud': 8,
#              'touch': 92,
#              'dream': 56,
#              'targaryen': 84,
#              'daenery': 611,
#              'pento': 11,
#              'narrow_sea': 25,
#              'large': 132,
#              'bride': 21,
#              'gift': 65,
#              'illyrio': 6,
#              'fabric': 8,
#              'mmmm': 2,
#              'isn_t': 37,
#              'gracious': 2,
#              'host': 16,
#              'guest': 33,
#              'forget': 91,
#              'throne': 149,
#              'slouch': 1,
#              'let': 468,
#              'gown': 17,
#              'endure': 8,
#              'stroke': 18,
#              'breast': 20,
#              'today': 80,
#              'wake': 47,
#              'dragon': 309,
#              'viserys': 42,
#              'write': 57,
#              'history': 42,
#              'reign': 22,
#              'sweet': 56,
#              'step': 241,
#              'steam': 3,
#              'hot': 17,
#              'bath': 26,
#              'despairing': 1,
#              'keep': 88,
#              'deeply': 26,
#              'illyrios': 1,
#              'mansion': 1,
#              'await': 19,
#              'khal_drogo': 59,
#              'dothraki': 216,
#              'punctuality': 1,
#              'wheel': 19,
#              'stallion': 10,
#              'greet': 26,
#              'present': 44,
#              'honored_guest': 7,
#              'house_targaryen': 19,
#              'rightful_king': 11,
#              'andal_man': 4,
#              'defeat': 82,
#              'combat': 9,
#              'cut': 220,
#              'braid': 6,
#              'world': 260,
#              'shame': 44,
#              'killer': 27,
#              'alive': 115,
#              'forward': 109,
#              'dear': 47,
#              'hesitate': 21,
#              'straight': 24,
#              'fear': 116,
#              'gaze': 25,
#              'lead': 222,
#              'horseman': 7,
#              'charge': 98,
#              'trust': 175,
#              'garden': 40,
#              'overlook': 18,
#              'sea': 139,
#              'soon': 136,
#              'cross_narrow': 9,
#              'secret': 48,
#              'toast': 15,
#              'stay': 181,
#              'wouldn_t': 33,
#              'lack': 15,
#              'caution': 3,
#              'common': 38,
#              'apology': 30,
#              'offense': 4,
#              'play': 72,
#              'drogo': 46,
#              'army': 281,
#              'pleadingly': 1,
#              'home': 223,
#              'tribe': 7,
#              'brotherly': 2,
#              'kiss_forehead': 6,
#              'bedroom': 12,
#              'fix': 12,
#              'ugly': 17,
#              'stupid': 63,
#              'roll': 34,
#              'marry': 142,
#              'hush': 11,
#              'hasn': 2,
#              't': 106,
#              'second': 62,
#              'powerful': 38,
#              'someday': 16,
#              'bawdy': 3,
#              'wench': 9,
#              'embarrass': 3,
#              'disgust': 16,
#              'frustration': 10,
#              'fencing': 1,
#              'dummy': 3,
#              'uncle_benjen': 8,
#              'big': 94,
#              'aren_t': 20,
#              'lady_stark': 45,
#              'insult': 34,
#              'seat': 85,
#              'bastard': 151,
#              'midst': 5,
#              'welcome': 64,
#              'refuse': 65,
#              'ready': 96,
#              'care': 111,
#              'rescue': 16,
#              'talk': 266,
#              'benjen': 22,
#              'uncle': 88,
#              'accomplishment': 3,
#              'ned_stark': 88,
#              'angry': 39,
#              'offend': 17,
#              'make': 168,
#              'advice': 24,
#              'armor': 67,
#              'hurt': 77,
#              'dwarf': 67,
#              'departs': 2,
#              'pick_sword': 16,
#              'attack': 151,
#              'ferocity': 1,
#              'raucous': 2,
#              'madness': 13,
#              'walker': 23,
#              'slaughter': 59,
#              'ambush': 6,
#              'maybe': 135,
#              'ye': 1,
#              'desperation': 4,
#              'lovely': 42,
#              'country': 37,
#              'observe': 8,
#              'm_sure': 18,
#              'grim': 7,
#              'scared': 22,
#              'shyly': 2,
#              'hello': 16,
#              'little_dove': 7,
#              'beauty': 34,
#              'thirteen': 18,
#              'share': 44,
#              'grandchild': 7,
#              'capital': 63,
#              'shouldn_t': 17,
#              'hide': 83,
#              'path': 50,
#              'neighbor': 1,
#              'tournament': 15,
#              'celebrate': 17,
#              'accept': 34,
#              'field': 56,
#              'competition': 2,
#              'stale': 2,
#              'fight': 608,
#              'real': 82,
#              'flip': 15,
#              'food': 92,
#              'deal': 38,
#              'hoist': 6,
#              'bed': 129,
#              'northman': 16,
#              'rat': 22,
#              'nest': 4,
#              'husband': 66,
#              'knock_door': 22,
#              'maester_luwin': 15,
#              'pardon': 37,
#              'seal': 24,
#              'note': 17,
#              'send': 210,
#              'eyrie': 31,
#              'wedding': 93,
#              'alarm': 2,
#              'murder': 184,
#              'danger': 13,
#              'fresh': 20,
#              'widow': 17,
#              'doesn_t': 47,
#              'lysa': 32,
#              'head_spike': 12,
#              'wrong': 118,
#              'letter': 54,
#              'risk_life': 13,
#              'wasn_t': 33,
#              'certain': 35,
#              'conspire': 16,
#              'protect': 155,
#              'swear': 155,
#              'spend': 39,
#              'half': 139,
#              'war': 303,
#              'owe': 40,
#              'ride_south': 12,
#              'demand': 44,
#              'different': 61,
#              'wild': 28,
#              'celebration': 13,
#              'fighting': 43,
#              'fornication': 4,
#              'looks': 2,
#              'stricken': 1,
#              'khal': 63,
#              'plan': 92,
#              'invasion': 3,
#              'crown': 89,
#              'shall': 120,
#              'omen': 1,
#              'favor': 23,
#              'piss': 43,
#              'omens': 1,
#              'sex': 5,
#              'violence': 13,
#              'intensify': 1,
#              'rape': 32,
#              'avidly': 1,
#              'consider': 45,
#              'dull': 16,
#              'affair': 15,
#              'knight': 139,
#              'westerosi': 10,
#              'garb': 5,
#              'appear': 105,
#              'jorah_mormont': 15,
#              'bear': 180,
#              'book': 86,
#              'small': 122,
#              'khaleesi': 101,
#              'song': 33,
#              'thank': 178,
#              'ser': 140,
#              'ser_jorah': 25,
#              'mormont': 50,
#              'bear_island': 11,
#              'dany': 23,
#              'chest': 68,
#              'dragon_egg': 8,
#              'shadow': 45,
#              'land': 133,
#              'asshai': 7,
#              'age': 25,
#              'stone': 81,
#              'magister': 5,
#              'stride': 18,
#              'sick': 9,
#              'crowd': 160,
#              'mare': 3,
#              'mount': 59,
#              'seaside': 3,
#              'sunset': 5,
#              'unwrap': 3,
#              'dress': 81,
#              'sob': 21,
#              'tear': 73,
#              'common_tongue': 10,
#              'bend': 20,
#              'rough': 14,
#              'squirt': 3,
#              'end': 183,
#              'miracle': 4,
#              'hunter': 9,
#              'spear': 99,
#              'loyal': 60,
#              'sure': 151,
#              'party': 53,
#              'goodbye': 19,
#              'sniff': 15,
#              'near': 59,
#              'moan': 11,
#              'peer': 12,
#              'window': 66,
#              'have_sex': 12,
#              'grab': 207,
#              'mad': 28,
#              'climber': 4,
#              'imploringly': 2,
#              'shove': 22,
#              'baelor': 23,
#              'execution': 4,
#              'ilyn_payne': 11,
#              'bloody': 89,
#              'rapturous': 1,
#              'townsfolk': 3,
#              'pan': 4,
#              'press': 21,
#              'yoren': 31,
#              'eh': 30,
#              'bright': 12,
#              'mouth': 80,
#              'shut': 49,
#              'mob': 9,
#              'flight': 12,
#              'stair': 42,
#              'faint': 11,
#              'knife': 134,
#              "l'm": 32,
#              'smart': 39,
#              'scream': 134,
#              'shout': 51,
#              'eyed_raven': 33,
#              'osha': 91,
#              'lt': 30,
#              'l': 207,
#              'hodor': 117,
#              'hole': 39,
#              'ground': 191,
#              'crippled_boy': 7,
#              'willing': 17,
#              'light': 76,
#              'torch': 52,
#              'grandfather': 27,
#              'rickard': 4,
#              'burn_alive': 12,
#              'mad_king': 41,
#              'aery': 3,
#              'suppose': 117,
#              'rhaegar_targaryen': 7,
#              'kidnap': 8,
#              'war_win': 13,
#              'rhaegar': 21,
#              'loud': 15,
#              'roar': 47,
#              'fall_ground': 41,
#              'shaggydog': 12,
#              'bark': 11,
#              'viciously': 1,
#              'chain': 105,
#              'kennel': 15,
#              'king_landing': 222,
#              'sleep': 113,
#              'rickon': 66,
#              'puzzled': 3,
#              'natural': 7,
#              'thought': 30,
#              'bannerman': 40,
#              'respectfully': 2,
#              'reach': 168,
#              'forest': 11,
#              'collapse': 32,
#              'grief': 5,
#              'sound': 79,
#              'slash': 7,
#              'nearby': 64,
#              'realize': 50,
#              'fully': 19,
#              'armoured': 4,
#              'ruin': 40,
#              'hug': 36,
#              'caress': 19,
#              'neck': 110,
#              'console': 5,
#              'shh_shh': 9,
#              'shh': 24,
#              "l'll": 19,
#              'throne_room': 49,
#              'marillion': 2,
#              'bard': 2,
#              'singe': 18,
#              'retinue': 1,
#              'cercei': 1,
#              'colonnade': 1,
#              'tusk': 2,
#              'bode': 1,
#              'ill': 14,
#              'brave': 42,
#              'lose': 179,
#              'battle': 176,
#              'fail': 54,
#              'final': 32,
#              'test': 8,
#              'ball': 33,
#              'amusing': 2,
#              "lsn't": 1,
#              'funny': 26,
#              'rendition': 1,
#              'imagine': 75,
#              'receive': 31,
#              'tavern': 20,
#              'sing': 36,
#              'despondent': 2,
#              'finger': 50,
#              'tongue': 33,
#              'lf': 16,
#              'cut_throat': 26,
#              'will': 199,
#              'llyn': 9,
#              'beg': 50,
#              'marche': 10,
#              'fire': 281,
#              'heat': 8,
#              'dagger': 91,
#              'matter': 153,
#              'meryn_trant': 21,
#              'nice': 54,
#              'bid': 5,
#              'walk_past': 53,
#              'row': 31,
#              'trant': 10,
#              'clegane': 27,
#              'pike': 7,
#              'impale': 7,
#              'point': 112,
#              'happen': 197,
#              'traitor': 79,
#              'merciful': 4,
#              'clean': 51,
#              'treason': 46,
#              'please': 7,
#              'septum': 15,
#              'shoot': 43,
#              'impaled': 1,
#              'traditional': 3,
#              'headscarf': 1,
#              'raise': 102,
#              'defiantly': 1,
#              'cower': 11,
#              'ser_meryn': 26,
#              'repeatedly': 22,
#              'lip': 29,
#              'notice': 76,
#              'street': 72,
#              'lunge': 10,
#              'edge': 44,
#              'rag': 10,
#              'lesson': 26,
#              'court': 22,
#              'save': 122,
#              'pain': 52,
#              'handkerchief': 1,
#              'sandor': 117,
#              'meeting': 35,
#              'sit_table': 45,
#              'torchlight': 2,
#              'renly': 109,
#              'stannis': 288,
#              'declare': 22,
#              'peace': 79,
#              'term': 25,
#              'iron': 28,
#              'chair': 43,
#              'extend': 16,
#              'king_north': 65,
#              'victory': 23,
#              'chant': 20,
#              'fealty': 9,
#              'wearily': 1,
#              ...})

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# ['man', 's', 'look', 'know', 'want', 'come', 'walk', 'tyrion', 'lord', 'king']

# %%
import multiprocessing

from gensim.models import Word2Vec

# %%
cores = multiprocessing.cpu_count() # Count the number of cores in a comput

# %%
cores
# Out:
# 8

# %%
w2v_model = Word2Vec(min_count=20, window=2, vector_size=500, sample=6e-5, alpha=0.03, min_alpha=0.0007, negative=20, workers=cores-1)
# Out:
# INFO - 08:06:00: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=0, vector_size=500, alpha=0.03>', 'datetime': '2023-03-01T08:06:00.683706', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'created'}

# %%
t = time()

w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 08:06:02: collecting all words and their counts
# INFO - 08:06:02: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 08:06:02: PROGRESS: at sentence #10000, processed 63096 words, keeping 6084 word types
# INFO - 08:06:02: PROGRESS: at sentence #20000, processed 133333 words, keeping 8252 word types
# INFO - 08:06:02: collected 9045 word types from a corpus of 168555 raw words and 24710 sentences
# INFO - 08:06:02: Creating a fresh vocabulary
# INFO - 08:06:02: Word2Vec lifecycle event {'msg': 'effective_min_count=20 retains 1439 unique words (15.91% of original 9045, drops 7606)', 'datetime': '2023-03-01T08:06:02.627180', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# INFO - 08:06:02: Word2Vec lifecycle event {'msg': 'effective_min_count=20 leaves 138037 word corpus (81.89% of original 168555, drops 30518)', 'datetime': '2023-03-01T08:06:02.628177', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# INFO - 08:06:02: deleting the raw counts dictionary of 9045 items
# INFO - 08:06:02: sample=6e-05 downsamples 1319 most-common words
# INFO - 08:06:02: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 46649.24274848576 word corpus (33.8%% of prior 138037)', 'datetime': '2023-03-01T08:06:02.648125', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# INFO - 08:06:02: estimated required memory for 1439 words and 500 dimensions: 6475500 bytes
# INFO - 08:06:02: resetting layer weights
# INFO - 08:06:02: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-03-01T08:06:02.677051', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'build_vocab'}
# Time to build vocab: 0.01 mins

# %%
t = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=200, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 08:06:08: Word2Vec lifecycle event {'msg': 'training model with 7 workers on 1439 vocabulary and 500 features, using sg=0 hs=0 sample=6e-05 negative=20 window=2 shrink_windows=True', 'datetime': '2023-03-01T08:06:08.726665', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'train'}
# INFO - 08:06:09: EPOCH 0: training on 168555 raw words (46682 effective words) took 0.4s, 113769 effective words/s
# INFO - 08:06:09: EPOCH 1: training on 168555 raw words (46711 effective words) took 0.4s, 117412 effective words/s
# INFO - 08:06:10: EPOCH 2: training on 168555 raw words (46617 effective words) took 0.4s, 108121 effective words/s
# INFO - 08:06:10: EPOCH 3: training on 168555 raw words (46612 effective words) took 0.3s, 135887 effective words/s
# INFO - 08:06:10: EPOCH 4: training on 168555 raw words (46748 effective words) took 0.4s, 133002 effective words/s
# INFO - 08:06:11: EPOCH 5: training on 168555 raw words (46551 effective words) took 0.4s, 125995 effective words/s
# INFO - 08:06:11: EPOCH 6: training on 168555 raw words (46853 effective words) took 0.3s, 134568 effective words/s
# INFO - 08:06:11: EPOCH 7: training on 168555 raw words (46531 effective words) took 0.4s, 124760 effective words/s
# INFO - 08:06:12: EPOCH 8: training on 168555 raw words (46879 effective words) took 0.8s, 56428 effective words/s
# INFO - 08:06:13: EPOCH 9: training on 168555 raw words (46922 effective words) took 0.4s, 107510 effective words/s
# INFO - 08:06:13: EPOCH 10: training on 168555 raw words (46704 effective words) took 0.4s, 132763 effective words/s
# INFO - 08:06:13: EPOCH 11: training on 168555 raw words (46499 effective words) took 0.4s, 129134 effective words/s
# INFO - 08:06:14: EPOCH 12: training on 168555 raw words (46882 effective words) took 0.4s, 122757 effective words/s
# INFO - 08:06:14: EPOCH 13: training on 168555 raw words (46685 effective words) took 0.4s, 124157 effective words/s
# INFO - 08:06:15: EPOCH 14: training on 168555 raw words (46962 effective words) took 0.4s, 111080 effective words/s
# INFO - 08:06:15: EPOCH 15: training on 168555 raw words (46668 effective words) took 0.4s, 119234 effective words/s
# INFO - 08:06:15: EPOCH 16: training on 168555 raw words (46727 effective words) took 0.4s, 127533 effective words/s
# INFO - 08:06:16: EPOCH 17: training on 168555 raw words (46455 effective words) took 0.4s, 123565 effective words/s
# INFO - 08:06:16: EPOCH 18: training on 168555 raw words (46590 effective words) took 0.4s, 126865 effective words/s
# INFO - 08:06:17: EPOCH 19: training on 168555 raw words (46802 effective words) took 0.7s, 71626 effective words/s
# INFO - 08:06:17: EPOCH 20: training on 168555 raw words (46520 effective words) took 0.4s, 125401 effective words/s
# INFO - 08:06:18: EPOCH 21: training on 168555 raw words (46714 effective words) took 0.4s, 119079 effective words/s
# INFO - 08:06:18: EPOCH 22: training on 168555 raw words (46515 effective words) took 0.4s, 126978 effective words/s
# INFO - 08:06:19: EPOCH 23: training on 168555 raw words (46574 effective words) took 0.4s, 127048 effective words/s
# INFO - 08:06:19: EPOCH 24: training on 168555 raw words (46478 effective words) took 0.4s, 127505 effective words/s
# INFO - 08:06:19: EPOCH 25: training on 168555 raw words (46770 effective words) took 0.3s, 137360 effective words/s
# INFO - 08:06:20: EPOCH 26: training on 168555 raw words (46761 effective words) took 0.3s, 136423 effective words/s
# INFO - 08:06:20: EPOCH 27: training on 168555 raw words (46713 effective words) took 0.4s, 130877 effective words/s
# INFO - 08:06:20: EPOCH 28: training on 168555 raw words (46686 effective words) took 0.4s, 133259 effective words/s
# INFO - 08:06:21: EPOCH 29: training on 168555 raw words (46689 effective words) took 0.4s, 116961 effective words/s
# INFO - 08:06:21: EPOCH 30: training on 168555 raw words (46502 effective words) took 0.6s, 79695 effective words/s
# INFO - 08:06:22: EPOCH 31: training on 168555 raw words (46660 effective words) took 0.4s, 119128 effective words/s
# INFO - 08:06:22: EPOCH 32: training on 168555 raw words (46359 effective words) took 0.4s, 130283 effective words/s
# INFO - 08:06:23: EPOCH 33: training on 168555 raw words (46621 effective words) took 0.4s, 130446 effective words/s
# INFO - 08:06:23: EPOCH 34: training on 168555 raw words (46623 effective words) took 0.3s, 136199 effective words/s
# INFO - 08:06:23: EPOCH 35: training on 168555 raw words (46653 effective words) took 0.4s, 120825 effective words/s
# INFO - 08:06:24: EPOCH 36: training on 168555 raw words (46567 effective words) took 0.4s, 132465 effective words/s
# INFO - 08:06:24: EPOCH 37: training on 168555 raw words (46789 effective words) took 0.4s, 129417 effective words/s
# INFO - 08:06:25: EPOCH 38: training on 168555 raw words (46652 effective words) took 0.4s, 126352 effective words/s
# INFO - 08:06:25: EPOCH 39: training on 168555 raw words (46712 effective words) took 0.4s, 128082 effective words/s
# INFO - 08:06:25: EPOCH 40: training on 168555 raw words (46843 effective words) took 0.4s, 126253 effective words/s
# INFO - 08:06:26: EPOCH 41: training on 168555 raw words (46719 effective words) took 0.7s, 71693 effective words/s
# INFO - 08:06:26: EPOCH 42: training on 168555 raw words (46800 effective words) took 0.4s, 122429 effective words/s
# INFO - 08:06:27: EPOCH 43: training on 168555 raw words (46801 effective words) took 0.3s, 135568 effective words/s
# INFO - 08:06:27: EPOCH 44: training on 168555 raw words (46612 effective words) took 0.4s, 123964 effective words/s
# INFO - 08:06:27: EPOCH 45: training on 168555 raw words (46589 effective words) took 0.3s, 143765 effective words/s
# INFO - 08:06:28: EPOCH 46: training on 168555 raw words (46719 effective words) took 0.3s, 151780 effective words/s
# INFO - 08:06:28: EPOCH 47: training on 168555 raw words (46518 effective words) took 0.4s, 131155 effective words/s
# INFO - 08:06:29: EPOCH 48: training on 168555 raw words (46785 effective words) took 0.4s, 130948 effective words/s
# INFO - 08:06:29: EPOCH 49: training on 168555 raw words (46504 effective words) took 0.3s, 135355 effective words/s
# INFO - 08:06:29: EPOCH 50: training on 168555 raw words (46570 effective words) took 0.3s, 133218 effective words/s
# INFO - 08:06:30: EPOCH 51: training on 168555 raw words (47063 effective words) took 0.4s, 124553 effective words/s
# INFO - 08:06:30: EPOCH 52: training on 168555 raw words (46565 effective words) took 0.4s, 130796 effective words/s
# INFO - 08:06:31: EPOCH 53: training on 168555 raw words (46358 effective words) took 0.6s, 73859 effective words/s
# INFO - 08:06:31: EPOCH 54: training on 168555 raw words (46811 effective words) took 0.4s, 129094 effective words/s
# INFO - 08:06:31: EPOCH 55: training on 168555 raw words (46618 effective words) took 0.3s, 136924 effective words/s
# INFO - 08:06:32: EPOCH 56: training on 168555 raw words (46607 effective words) took 0.4s, 118639 effective words/s
# INFO - 08:06:32: EPOCH 57: training on 168555 raw words (46578 effective words) took 0.4s, 127216 effective words/s
# INFO - 08:06:33: EPOCH 58: training on 168555 raw words (46768 effective words) took 0.4s, 131908 effective words/s
# INFO - 08:06:33: EPOCH 59: training on 168555 raw words (46742 effective words) took 0.3s, 135547 effective words/s
# INFO - 08:06:33: EPOCH 60: training on 168555 raw words (46726 effective words) took 0.4s, 128326 effective words/s
# INFO - 08:06:34: EPOCH 61: training on 168555 raw words (46685 effective words) took 0.4s, 131869 effective words/s
# INFO - 08:06:34: EPOCH 62: training on 168555 raw words (46736 effective words) took 0.4s, 129836 effective words/s
# INFO - 08:06:35: EPOCH 63: training on 168555 raw words (46800 effective words) took 0.3s, 140024 effective words/s
# INFO - 08:06:35: EPOCH 64: training on 168555 raw words (46650 effective words) took 0.3s, 164755 effective words/s
# INFO - 08:06:36: EPOCH 65: training on 168555 raw words (46739 effective words) took 0.3s, 140280 effective words/s
# INFO - 08:06:36: EPOCH 66: training on 168555 raw words (46462 effective words) took 0.3s, 141060 effective words/s
# INFO - 08:06:36: EPOCH 67: training on 168555 raw words (46522 effective words) took 0.3s, 133560 effective words/s
# INFO - 08:06:37: EPOCH 68: training on 168555 raw words (46620 effective words) took 0.4s, 132455 effective words/s
# INFO - 08:06:37: EPOCH 69: training on 168555 raw words (46664 effective words) took 0.3s, 151161 effective words/s
# INFO - 08:06:37: EPOCH 70: training on 168555 raw words (46564 effective words) took 0.4s, 123135 effective words/s
# INFO - 08:06:38: EPOCH 71: training on 168555 raw words (46754 effective words) took 0.3s, 140207 effective words/s
# INFO - 08:06:38: EPOCH 72: training on 168555 raw words (46599 effective words) took 0.3s, 167068 effective words/s
# INFO - 08:06:38: EPOCH 73: training on 168555 raw words (46839 effective words) took 0.3s, 135029 effective words/s
# INFO - 08:06:39: EPOCH 74: training on 168555 raw words (46677 effective words) took 0.4s, 122979 effective words/s
# INFO - 08:06:39: EPOCH 75: training on 168555 raw words (46665 effective words) took 0.6s, 72194 effective words/s
# INFO - 08:06:40: EPOCH 76: training on 168555 raw words (46859 effective words) took 0.4s, 132240 effective words/s
# INFO - 08:06:40: EPOCH 77: training on 168555 raw words (46710 effective words) took 0.4s, 131635 effective words/s
# INFO - 08:06:41: EPOCH 78: training on 168555 raw words (46587 effective words) took 0.4s, 130663 effective words/s
# INFO - 08:06:41: EPOCH 79: training on 168555 raw words (46883 effective words) took 0.4s, 120701 effective words/s
# INFO - 08:06:41: EPOCH 80: training on 168555 raw words (46580 effective words) took 0.4s, 130395 effective words/s
# INFO - 08:06:42: EPOCH 81: training on 168555 raw words (46566 effective words) took 0.3s, 142790 effective words/s
# INFO - 08:06:42: EPOCH 82: training on 168555 raw words (46707 effective words) took 0.4s, 133298 effective words/s
# INFO - 08:06:42: EPOCH 83: training on 168555 raw words (46657 effective words) took 0.3s, 152455 effective words/s
# INFO - 08:06:43: EPOCH 84: training on 168555 raw words (46633 effective words) took 0.3s, 135092 effective words/s
# INFO - 08:06:43: EPOCH 85: training on 168555 raw words (46669 effective words) took 0.4s, 130892 effective words/s
# INFO - 08:06:44: EPOCH 86: training on 168555 raw words (46651 effective words) took 0.6s, 72899 effective words/s
# INFO - 08:06:44: EPOCH 87: training on 168555 raw words (46735 effective words) took 0.4s, 133283 effective words/s
# INFO - 08:06:45: EPOCH 88: training on 168555 raw words (46469 effective words) took 0.4s, 132021 effective words/s
# INFO - 08:06:45: EPOCH 89: training on 168555 raw words (46757 effective words) took 0.3s, 134321 effective words/s
# INFO - 08:06:45: EPOCH 90: training on 168555 raw words (46700 effective words) took 0.3s, 146681 effective words/s
# INFO - 08:06:46: EPOCH 91: training on 168555 raw words (46522 effective words) took 0.3s, 132960 effective words/s
# INFO - 08:06:46: EPOCH 92: training on 168555 raw words (46742 effective words) took 0.3s, 133738 effective words/s
# INFO - 08:06:46: EPOCH 93: training on 168555 raw words (46616 effective words) took 0.4s, 112286 effective words/s
# INFO - 08:06:47: EPOCH 94: training on 168555 raw words (46496 effective words) took 0.4s, 126290 effective words/s
# INFO - 08:06:47: EPOCH 95: training on 168555 raw words (46670 effective words) took 0.4s, 132833 effective words/s
# INFO - 08:06:48: EPOCH 96: training on 168555 raw words (46501 effective words) took 0.4s, 131602 effective words/s
# INFO - 08:06:48: EPOCH 97: training on 168555 raw words (46597 effective words) took 0.6s, 73470 effective words/s
# INFO - 08:06:49: EPOCH 98: training on 168555 raw words (46616 effective words) took 0.3s, 137111 effective words/s
# INFO - 08:06:49: EPOCH 99: training on 168555 raw words (46900 effective words) took 0.3s, 136234 effective words/s
# INFO - 08:06:49: EPOCH 100: training on 168555 raw words (46757 effective words) took 0.4s, 131555 effective words/s
# INFO - 08:06:50: EPOCH 101: training on 168555 raw words (46684 effective words) took 0.3s, 144397 effective words/s
# INFO - 08:06:50: EPOCH 102: training on 168555 raw words (46814 effective words) took 0.3s, 149602 effective words/s
# INFO - 08:06:50: EPOCH 103: training on 168555 raw words (46676 effective words) took 0.4s, 124274 effective words/s
# INFO - 08:06:51: EPOCH 104: training on 168555 raw words (46662 effective words) took 0.4s, 132166 effective words/s
# INFO - 08:06:51: EPOCH 105: training on 168555 raw words (46766 effective words) took 0.3s, 139860 effective words/s
# INFO - 08:06:52: EPOCH 106: training on 168555 raw words (46704 effective words) took 0.3s, 158132 effective words/s
# INFO - 08:06:52: EPOCH 107: training on 168555 raw words (46517 effective words) took 0.3s, 141905 effective words/s
# INFO - 08:06:52: EPOCH 108: training on 168555 raw words (46851 effective words) took 0.3s, 142150 effective words/s
# INFO - 08:06:53: EPOCH 109: training on 168555 raw words (46687 effective words) took 0.7s, 68911 effective words/s
# INFO - 08:06:53: EPOCH 110: training on 168555 raw words (46420 effective words) took 0.4s, 130031 effective words/s
# INFO - 08:06:54: EPOCH 111: training on 168555 raw words (46686 effective words) took 0.4s, 122625 effective words/s
# INFO - 08:06:54: EPOCH 112: training on 168555 raw words (46657 effective words) took 0.4s, 118067 effective words/s
# INFO - 08:06:55: EPOCH 113: training on 168555 raw words (46968 effective words) took 0.4s, 129911 effective words/s
# INFO - 08:06:55: EPOCH 114: training on 168555 raw words (46664 effective words) took 0.3s, 136291 effective words/s
# INFO - 08:06:55: EPOCH 115: training on 168555 raw words (46379 effective words) took 0.4s, 122688 effective words/s
# INFO - 08:06:56: EPOCH 116: training on 168555 raw words (46728 effective words) took 0.4s, 105769 effective words/s
# INFO - 08:06:56: EPOCH 117: training on 168555 raw words (46592 effective words) took 0.4s, 132091 effective words/s
# INFO - 08:06:56: EPOCH 118: training on 168555 raw words (46637 effective words) took 0.4s, 127469 effective words/s
# INFO - 08:06:57: EPOCH 119: training on 168555 raw words (46646 effective words) took 0.7s, 70631 effective words/s
# INFO - 08:06:58: EPOCH 120: training on 168555 raw words (46505 effective words) took 0.4s, 108801 effective words/s
# INFO - 08:06:58: EPOCH 121: training on 168555 raw words (46679 effective words) took 0.4s, 126276 effective words/s
# INFO - 08:06:58: EPOCH 122: training on 168555 raw words (46746 effective words) took 0.4s, 123538 effective words/s
# INFO - 08:06:59: EPOCH 123: training on 168555 raw words (46627 effective words) took 0.4s, 125213 effective words/s
# INFO - 08:06:59: EPOCH 124: training on 168555 raw words (46594 effective words) took 0.3s, 133302 effective words/s
# INFO - 08:07:00: EPOCH 125: training on 168555 raw words (46468 effective words) took 0.4s, 126511 effective words/s
# INFO - 08:07:00: EPOCH 126: training on 168555 raw words (46860 effective words) took 0.4s, 124439 effective words/s
# INFO - 08:07:00: EPOCH 127: training on 168555 raw words (46648 effective words) took 0.4s, 124632 effective words/s
# INFO - 08:07:01: EPOCH 128: training on 168555 raw words (46781 effective words) took 0.3s, 133798 effective words/s
# INFO - 08:07:01: EPOCH 129: training on 168555 raw words (46618 effective words) took 0.3s, 133820 effective words/s
# INFO - 08:07:02: EPOCH 130: training on 168555 raw words (46562 effective words) took 0.7s, 66564 effective words/s
# INFO - 08:07:02: EPOCH 131: training on 168555 raw words (47024 effective words) took 0.4s, 119649 effective words/s
# INFO - 08:07:03: EPOCH 132: training on 168555 raw words (46783 effective words) took 0.4s, 112328 effective words/s
# INFO - 08:07:03: EPOCH 133: training on 168555 raw words (46599 effective words) took 0.4s, 123735 effective words/s
# INFO - 08:07:03: EPOCH 134: training on 168555 raw words (46589 effective words) took 0.4s, 125616 effective words/s
# INFO - 08:07:04: EPOCH 135: training on 168555 raw words (46713 effective words) took 0.4s, 121442 effective words/s
# INFO - 08:07:04: EPOCH 136: training on 168555 raw words (46823 effective words) took 0.3s, 140068 effective words/s
# INFO - 08:07:05: EPOCH 137: training on 168555 raw words (46756 effective words) took 0.4s, 128998 effective words/s
# INFO - 08:07:05: EPOCH 138: training on 168555 raw words (46673 effective words) took 0.3s, 136897 effective words/s
# INFO - 08:07:05: EPOCH 139: training on 168555 raw words (46753 effective words) took 0.4s, 129962 effective words/s
# INFO - 08:07:06: EPOCH 140: training on 168555 raw words (46512 effective words) took 0.4s, 113622 effective words/s
# INFO - 08:07:07: EPOCH 141: training on 168555 raw words (46679 effective words) took 0.7s, 69328 effective words/s
# INFO - 08:07:07: EPOCH 142: training on 168555 raw words (46431 effective words) took 0.3s, 133541 effective words/s
# INFO - 08:07:07: EPOCH 143: training on 168555 raw words (46671 effective words) took 0.3s, 134877 effective words/s
# INFO - 08:07:08: EPOCH 144: training on 168555 raw words (46878 effective words) took 0.4s, 129426 effective words/s
# INFO - 08:07:08: EPOCH 145: training on 168555 raw words (46632 effective words) took 0.4s, 127113 effective words/s
# INFO - 08:07:08: EPOCH 146: training on 168555 raw words (46721 effective words) took 0.4s, 123520 effective words/s
# INFO - 08:07:09: EPOCH 147: training on 168555 raw words (46966 effective words) took 0.4s, 130857 effective words/s
# INFO - 08:07:09: EPOCH 148: training on 168555 raw words (46513 effective words) took 0.4s, 128097 effective words/s
# INFO - 08:07:10: EPOCH 149: training on 168555 raw words (46900 effective words) took 0.4s, 121041 effective words/s
# INFO - 08:07:10: EPOCH 150: training on 168555 raw words (46543 effective words) took 0.3s, 135597 effective words/s
# INFO - 08:07:10: EPOCH 151: training on 168555 raw words (46558 effective words) took 0.4s, 116037 effective words/s
# INFO - 08:07:11: EPOCH 152: training on 168555 raw words (46239 effective words) took 0.6s, 73361 effective words/s
# INFO - 08:07:12: EPOCH 153: training on 168555 raw words (46726 effective words) took 0.4s, 109285 effective words/s
# INFO - 08:07:12: EPOCH 154: training on 168555 raw words (46807 effective words) took 0.4s, 121178 effective words/s
# INFO - 08:07:12: EPOCH 155: training on 168555 raw words (46553 effective words) took 0.4s, 105643 effective words/s
# INFO - 08:07:13: EPOCH 156: training on 168555 raw words (46425 effective words) took 0.4s, 127895 effective words/s
# INFO - 08:07:13: EPOCH 157: training on 168555 raw words (46591 effective words) took 0.4s, 128833 effective words/s
# INFO - 08:07:14: EPOCH 158: training on 168555 raw words (46399 effective words) took 0.4s, 112414 effective words/s
# INFO - 08:07:14: EPOCH 159: training on 168555 raw words (46696 effective words) took 0.4s, 126825 effective words/s
# INFO - 08:07:14: EPOCH 160: training on 168555 raw words (46685 effective words) took 0.4s, 129378 effective words/s
# INFO - 08:07:15: EPOCH 161: training on 168555 raw words (46798 effective words) took 0.4s, 128287 effective words/s
# INFO - 08:07:15: EPOCH 162: training on 168555 raw words (46476 effective words) took 0.4s, 124852 effective words/s
# INFO - 08:07:16: EPOCH 163: training on 168555 raw words (46840 effective words) took 0.6s, 73590 effective words/s
# INFO - 08:07:16: EPOCH 164: training on 168555 raw words (46575 effective words) took 0.3s, 146855 effective words/s
# INFO - 08:07:17: EPOCH 165: training on 168555 raw words (46544 effective words) took 0.2s, 238754 effective words/s
# INFO - 08:07:17: EPOCH 166: training on 168555 raw words (46626 effective words) took 0.4s, 128807 effective words/s
# INFO - 08:07:17: EPOCH 167: training on 168555 raw words (46596 effective words) took 0.4s, 124308 effective words/s
# INFO - 08:07:18: EPOCH 168: training on 168555 raw words (46699 effective words) took 0.4s, 123058 effective words/s
# INFO - 08:07:18: EPOCH 169: training on 168555 raw words (46390 effective words) took 0.4s, 110162 effective words/s
# INFO - 08:07:19: EPOCH 170: training on 168555 raw words (46852 effective words) took 0.4s, 127145 effective words/s
# INFO - 08:07:19: EPOCH 171: training on 168555 raw words (46663 effective words) took 0.3s, 149118 effective words/s
# INFO - 08:07:19: EPOCH 172: training on 168555 raw words (46744 effective words) took 0.4s, 124488 effective words/s
# INFO - 08:07:20: EPOCH 173: training on 168555 raw words (46575 effective words) took 0.4s, 127170 effective words/s
# INFO - 08:07:20: EPOCH 174: training on 168555 raw words (46697 effective words) took 0.3s, 139361 effective words/s
# INFO - 08:07:21: EPOCH 175: training on 168555 raw words (46491 effective words) took 0.6s, 73659 effective words/s
# INFO - 08:07:21: EPOCH 176: training on 168555 raw words (46555 effective words) took 0.3s, 136834 effective words/s
# INFO - 08:07:21: EPOCH 177: training on 168555 raw words (46444 effective words) took 0.3s, 148396 effective words/s
# INFO - 08:07:22: EPOCH 178: training on 168555 raw words (46544 effective words) took 0.3s, 149193 effective words/s
# INFO - 08:07:22: EPOCH 179: training on 168555 raw words (46655 effective words) took 0.4s, 130226 effective words/s
# INFO - 08:07:22: EPOCH 180: training on 168555 raw words (46924 effective words) took 0.3s, 141672 effective words/s
# INFO - 08:07:23: EPOCH 181: training on 168555 raw words (46668 effective words) took 0.3s, 137319 effective words/s
# INFO - 08:07:23: EPOCH 182: training on 168555 raw words (46884 effective words) took 0.3s, 165305 effective words/s
# INFO - 08:07:23: EPOCH 183: training on 168555 raw words (46603 effective words) took 0.4s, 132826 effective words/s
# INFO - 08:07:24: EPOCH 184: training on 168555 raw words (46500 effective words) took 0.4s, 124620 effective words/s
# INFO - 08:07:24: EPOCH 185: training on 168555 raw words (46553 effective words) took 0.3s, 137282 effective words/s
# INFO - 08:07:25: EPOCH 186: training on 168555 raw words (46474 effective words) took 0.3s, 150816 effective words/s
# INFO - 08:07:25: EPOCH 187: training on 168555 raw words (46754 effective words) took 0.6s, 75596 effective words/s
# INFO - 08:07:26: EPOCH 188: training on 168555 raw words (46397 effective words) took 0.3s, 142305 effective words/s
# INFO - 08:07:26: EPOCH 189: training on 168555 raw words (46895 effective words) took 0.3s, 168237 effective words/s
# INFO - 08:07:26: EPOCH 190: training on 168555 raw words (46505 effective words) took 0.3s, 133435 effective words/s
# INFO - 08:07:27: EPOCH 191: training on 168555 raw words (46801 effective words) took 0.3s, 135516 effective words/s
# INFO - 08:07:27: EPOCH 192: training on 168555 raw words (46668 effective words) took 0.3s, 133712 effective words/s
# INFO - 08:07:27: EPOCH 193: training on 168555 raw words (46617 effective words) took 0.3s, 136880 effective words/s
# INFO - 08:07:28: EPOCH 194: training on 168555 raw words (46525 effective words) took 0.4s, 132341 effective words/s
# INFO - 08:07:28: EPOCH 195: training on 168555 raw words (46483 effective words) took 0.4s, 132445 effective words/s
# INFO - 08:07:28: EPOCH 196: training on 168555 raw words (46724 effective words) took 0.3s, 134213 effective words/s
# INFO - 08:07:29: EPOCH 197: training on 168555 raw words (46610 effective words) took 0.3s, 140759 effective words/s
# INFO - 08:07:29: EPOCH 198: training on 168555 raw words (46628 effective words) took 0.6s, 76676 effective words/s
# INFO - 08:07:30: EPOCH 199: training on 168555 raw words (46719 effective words) took 0.3s, 140372 effective words/s
# INFO - 08:07:30: Word2Vec lifecycle event {'msg': 'training on 33711000 raw words (9331850 effective words) took 81.6s, 114368 effective words/s', 'datetime': '2023-03-01T08:07:30.323497', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'train'}
# Time to train the model: 1.36 mins

# %%
w2v_model.init_sims(replace=True)
# Out:
# C:\Users\abhij\AppData\Local\Temp\ipykernel_14128\514372312.py:1: DeprecationWarning:
#
# Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#
# WARNING - 08:07:36: destructive init_sims(replace=True) deprecated & no longer required for space-efficiency

# %%
w2v_model.wv.most_similar(positive=["baratheon"])
# Out:
# [('stannis', 0.23953251540660858),
#  ('short', 0.23146995902061462),
#  ('lannister', 0.22861948609352112),
#  ('walk_forward', 0.2242448627948761),
#  ('advance', 0.2190706729888916),
#  ('banner', 0.21905829012393951),
#  ('form', 0.21278077363967896),
#  ('stannis_baratheon', 0.2127538025379181),
#  ('party', 0.20951353013515472),
#  ('mace', 0.20861847698688507)]

# %%
w2v_model.wv.most_similar(positive=["lannister"])
# Out:
# [('tywin', 0.27474284172058105),
#  ('son', 0.2568546533584595),
#  ('tywin_lannister', 0.2560979723930359),
#  ('refuse', 0.25184348225593567),
#  ('frey', 0.24865394830703735),
#  ('family', 0.23525550961494446),
#  ('iron_bank', 0.23485049605369568),
#  ('stark', 0.2340048998594284),
#  ('tyrell', 0.2310585081577301),
#  ('nephew', 0.22907152771949768)]

# %%
w2v_model.wv.most_similar(positive=["stark"])
# Out:
# [('winterfell', 0.34082770347595215),
#  ('bolton', 0.3261927366256714),
#  ('tully', 0.29228541254997253),
#  ('frey', 0.2845751941204071),
#  ('banner', 0.28376504778862),
#  ('warden_north', 0.2498905062675476),
#  ('catelyn_stark', 0.246596097946167),
#  ('shield', 0.23977579176425934),
#  ('lannister', 0.2340048998594284),
#  ('house_stark', 0.22942805290222168)]

# %%
w2v_model.wv.most_similar(positive=["targaryen"])
# Out:
# [('westero', 0.3207218050956726),
#  ('mad_king', 0.31438544392585754),
#  ('rebellion', 0.2999190092086792),
#  ('seven_kingdom', 0.27919113636016846),
#  ('aegon', 0.2781907021999359),
#  ('rhaegar', 0.2578057646751404),
#  ('kingdom', 0.25489428639411926),
#  ('realm', 0.24933253228664398),
#  ('century', 0.24461926519870758),
#  ('year_ago', 0.2335478514432907)]

# %%
w2v_model.wv.most_similar(positive=["robb"])
# Out:
# [('talisa', 0.5508999824523926),
#  ('catelyn', 0.43172067403793335),
#  ('roslin', 0.42848455905914307),
#  ('walder', 0.39282119274139404),
#  ('rickard_karstark', 0.378397136926651),
#  ('frey', 0.3640487790107727),
#  ('edmure', 0.357572078704834),
#  ('roose', 0.35129210352897644),
#  ('brynden', 0.3361089527606964),
#  ('twin', 0.3055846095085144)]

# %%
w2v_model.wv.most_similar(positive=["hound"])
# Out:
# [('polliver', 0.4304107427597046),
#  ('arya', 0.4226236939430237),
#  ('beric', 0.3682827353477478),
#  ('fall_ground', 0.3541356027126312),
#  ('gut', 0.34398970007896423),
#  ('blow', 0.34219831228256226),
#  ('sandor', 0.338631272315979),
#  ('brienne', 0.33013981580734253),
#  ('stumble', 0.3244004547595978),
#  ('soldier', 0.32019343972206116)]

# %%
w2v_model.wv.most_similar(positive=["jon"])
# Out:
# [('tormund', 0.5142539739608765),
#  ('ygritte', 0.46753817796707153),
#  ('edd', 0.449279248714447),
#  ('sam', 0.4248664975166321),
#  ('davos', 0.4190618395805359),
#  ('olly', 0.4113067090511322),
#  ('grenn', 0.4062921106815338),
#  ('orell', 0.4014999270439148),
#  ('shoulder', 0.3761765956878662),
#  ('qhorin', 0.36831140518188477)]

# %%
w2v_model.wv.most_similar(positive=["white_walker"])
# Out:
# [('army_dead', 0.4678243100643158),
#  ('child_forest', 0.46315449476242065),
#  ('dragonglass', 0.36464279890060425),
#  ('walker', 0.3539915382862091),
#  ('leaf', 0.35024288296699524),
#  ('ice', 0.31917911767959595),
#  ('thousand_year', 0.3183048963546753),
#  ('meera', 0.2869231104850769),
#  ('sam', 0.28154855966567993),
#  ('wildling', 0.2746915817260742)]

# %%
w2v_model.wv.most_similar(positive=["castle_black"])
# Out:
# [('mance', 0.4235215187072754),
#  ('lord_commander', 0.36043381690979004),
#  ('wildling', 0.36023959517478943),
#  ('night_watch', 0.34556323289871216),
#  ('wall', 0.3302054703235626),
#  ('mance_rayder', 0.30206263065338135),
#  ('orell', 0.29435157775878906),
#  ('north', 0.28205788135528564),
#  ('qhorin', 0.2761329710483551),
#  ('pyp', 0.2655641436576843)]

# %%
w2v_model.wv.most_similar(positive=["winterfell"])
# Out:
# [('stark', 0.34082770347595215),
#  ('north', 0.3393135964870453),
#  ('raven', 0.3218349814414978),
#  ('banner', 0.31451213359832764),
#  ('warden_north', 0.2974699139595032),
#  ('bolton', 0.29463398456573486),
#  ('bran_rickon', 0.27875667810440063),
#  ('bannerman', 0.27061814069747925),
#  ('roose_bolton', 0.2639978229999542),
#  ('umber', 0.25930649042129517)]

# %%
w2v_model.wv.most_similar(positive=['king', 'targaryen'], negative=["baratheon"])
# Out:
# [('father', 0.3520020842552185),
#  ('queen', 0.319766104221344),
#  ('think', 0.289492130279541),
#  ('capital', 0.28795862197875977),
#  ('know', 0.28746360540390015),
#  ('realm', 0.2849137783050537),
#  ('believe', 0.2702147662639618),
#  ('swear', 0.2672134339809418),
#  ('want', 0.2651638388633728),
#  ('grace', 0.26504966616630554)]

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
import plotly.express as px
import plotly.graph_objs as go

import nltk
nltk.download('averaged_perceptron_tagger')

def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in model.wv.index_to_key:
        tokens.append(model.wv.get_vector(word))
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=3, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(np.array(tokens))

#     fig = px.scatter_3d(
#         new_values, x=0, y=1, z=2,
#         color=df.Speaker, labels={'color': 'species'}
#     )
#     fig.update_traces(marker_size=8)
#     fig.show()

    

    x = []
    y = []

    for value in new_values:
        x.append(value[0])
        y.append(value[1])

    fig = go.Figure()

    for i in range(len(x)):
        fig.add_trace(go.Scatter(x=[x[i]], y=[y[i]],
                        mode='markers+text',
                        text=[labels[i]],
                        textposition='bottom center',
                        marker=dict(size=10)))

    fig.update_layout(
        title="2D tsne plot all wordvecs",
        xaxis_title="X-axis",
        yaxis_title="Y-axis",
        showlegend=False,
        width=800,
        height=800,
        margin=dict(l=40, r=40, t=80, b=40),
    )

    fig.show()

    
    
#     x = []
#     y = []
#     for value in new_values:
#         x.append(value[0])
#         y.append(value[1])
        
#     plt.figure(figsize=(16, 16)) 
#     for i in range(len(x)):
#         plt.scatter(x[i],y[i])
#         plt.annotate(labels[i],
#                      xy=(x[i], y[i]),
#                      xytext=(5, 2),
#                      textcoords='offset points',
#                      ha='right',
#                      va='bottom')
#     plt.show()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\abhij\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
tsne_plot(w2v_model)
# Out:
# <div>                            <div id="c7b2c0d3-b87a-4cd2-8e01-19a362e9820b" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7b2c0d3-b87a-4cd2-8e01-19a362e9820b")) {                    Plotly.newPlot(                        "c7b2c0d3-b87a-4cd2-8e01-19a362e9820b",                        [{"marker":{"size":10},"mode":"markers+text","text":["man"],"textposition":"bottom center","x":[-27.38452911376953],"y":[26.508516311645508],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["s"],"textposition":"bottom center","x":[-35.09543991088867],"y":[13.14405632019043],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["look"],"textposition":"bottom center","x":[-28.582721710205078],"y":[-11.01402473449707],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["know"],"textposition":"bottom center","x":[28.189746856689453],"y":[-8.203716278076172],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["want"],"textposition":"bottom center","x":[29.723329544067383],"y":[-5.794221878051758],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["come"],"textposition":"bottom center","x":[36.88597869873047],"y":[-14.730865478515625],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["walk"],"textposition":"bottom center","x":[-23.258089065551758],"y":[-9.339839935302734],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["tyrion"],"textposition":"bottom center","x":[-14.596339225769043],"y":[-15.648706436157227],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["lord"],"textposition":"bottom center","x":[26.705530166625977],"y":[4.465854167938232],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["king"],"textposition":"bottom center","x":[28.88248062133789],"y":[1.7883203029632568],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["jon"],"textposition":"bottom center","x":[-12.799696922302246],"y":[12.864891052246094],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["stand"],"textposition":"bottom center","x":[-25.25484275817871],"y":[-8.202256202697754],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["like"],"textposition":"bottom center","x":[13.978958129882812],"y":[-14.755071640014648],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["hand"],"textposition":"bottom center","x":[-25.13313865661621],"y":[-2.1059746742248535],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["think"],"textposition":"bottom center","x":[25.686004638671875],"y":[-10.646075248718262],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["father"],"textposition":"bottom center","x":[26.781131744384766],"y":[-0.01822381466627121],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["tell"],"textposition":"bottom center","x":[27.75524139404297],"y":[-6.387193202972412],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["arya"],"textposition":"bottom center","x":[-17.88465118408203],"y":[-1.6053476333618164],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["kill"],"textposition":"bottom center","x":[10.094547271728516],"y":[-21.259157180786133],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["good"],"textposition":"bottom center","x":[23.130577087402344],"y":[-12.522141456604004],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["jaime"],"textposition":"bottom center","x":[-35.92704391479492],"y":[4.1670241355896],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["leave"],"textposition":"bottom center","x":[-28.821548461914062],"y" ...

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\abhij\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
fig = go.Figure()

for i in range(len(x)):
    
   # returns a document of object
    doc = nlp(labels[i])

    # checking if it is a noun or not
    if(doc[0].tag_ in ['NNP', 'NNPS']):
        fig.add_trace(go.Scatter(x=[x[i]], y=[y[i]],
                                 mode='markers+text',
                                 text=[labels[i]],
                                 textposition='bottom center',
                                 marker=dict(size=10)))
    else:
        pass
    
   

fig.update_layout(
    title="Tsne proper nouns only v1",
    xaxis_title="X-axis",
    yaxis_title="Y-axis",
    showlegend=False,
    width=800,
    height=800,
    margin=dict(l=40, r=40, t=80, b=40),
)

fig.show()
# Out:
# <div>                            <div id="3541f354-5348-4543-af33-7f8a4594420e" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3541f354-5348-4543-af33-7f8a4594420e")) {                    Plotly.newPlot(                        "3541f354-5348-4543-af33-7f8a4594420e",                        [{"marker":{"size":10},"mode":"markers+text","text":["lord"],"textposition":"bottom center","x":[24.315349578857422],"y":[5.5971150398254395],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["jon"],"textposition":"bottom center","x":[-11.0949125289917],"y":[-24.249719619750977],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["father"],"textposition":"bottom center","x":[21.983570098876953],"y":[3.165437698364258],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["sansa"],"textposition":"bottom center","x":[-11.103165626525879],"y":[16.97391700744629],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["lady"],"textposition":"bottom center","x":[23.383148193359375],"y":[6.173327922821045],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["boy"],"textposition":"bottom center","x":[15.651039123535156],"y":[22.31658172607422],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["bran"],"textposition":"bottom center","x":[-18.17171287536621],"y":[9.826386451721191],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["sam"],"textposition":"bottom center","x":[-7.544477939605713],"y":[-25.118675231933594],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["brienne"],"textposition":"bottom center","x":[-19.636924743652344],"y":[-7.047758102416992],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["jorah"],"textposition":"bottom center","x":[-13.778736114501953],"y":[8.08511734008789],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["god"],"textposition":"bottom center","x":[33.759700775146484],"y":[7.011960983276367],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["davos"],"textposition":"bottom center","x":[-13.011062622070312],"y":[0.2628607749938965],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["bronn"],"textposition":"bottom center","x":[-22.425731658935547],"y":[-8.836084365844727],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["dothraki"],"textposition":"bottom center","x":[-7.56638765335083],"y":[0.9370441436767578],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["catelyn"],"textposition":"bottom center","x":[1.5340135097503662],"y":[-20.442689895629883],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["gendry"],"textposition":"bottom center","x":[-12.320427894592285],"y":[-3.2229843139648438],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["robert"],"textposition":"bottom center","x":[26.246803283691406],"y":[-8.62685489654541],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["knight"],"textposition":"bottom center","x":[26.330551147460938],"y":[-18.282806396484375],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["red"],"textposition":"bottom center","x":[-15.776707649230957],"y":[31.451129913330078],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["hodor"],"textposition":"bottom center","x":[-17.303720474243164],"y":[7.867206573486328],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["bolton"],"textposition":"bottom center","x":[6.347208499908447],"y":[-20.475378036499023],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["loras"],"textposition":"bottom center","x":[-24.6949691 ...

# %%
all_characters = []
for s in df[df["Speaker"].notnull()]["Speaker"].unique():
    all_characters.append(s.split()[0].lower())


fig = go.Figure()

for i in range(len(x)):
    if(labels[i].strip() in all_characters):
        doc = nlp(labels[i])

        # checking if it is a noun or not
        if(doc[0].tag_ in ['NNP', 'NNPS']):
            fig.add_trace(go.Scatter(x=[x[i]], y=[y[i]],
                                     mode='markers+text',
                                     text=[labels[i]],
                                     textposition='bottom center',
                                     marker=dict(size=10)))
    else:
        pass
    
   

fig.update_layout(
    title="Tsne proper nouns only v2",
    xaxis_title="X-axis",
    yaxis_title="Y-axis",
    showlegend=False,
    width=800,
    height=800,
    margin=dict(l=40, r=40, t=80, b=40),
)

fig.show()
# Out:
# <div>                            <div id="5993f210-7240-45d8-8913-533c174b0018" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5993f210-7240-45d8-8913-533c174b0018")) {                    Plotly.newPlot(                        "5993f210-7240-45d8-8913-533c174b0018",                        [{"marker":{"size":10},"mode":"markers+text","text":["lord"],"textposition":"bottom center","x":[24.315349578857422],"y":[5.5971150398254395],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["jon"],"textposition":"bottom center","x":[-11.0949125289917],"y":[-24.249719619750977],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["sansa"],"textposition":"bottom center","x":[-11.103165626525879],"y":[16.97391700744629],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["lady"],"textposition":"bottom center","x":[23.383148193359375],"y":[6.173327922821045],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["boy"],"textposition":"bottom center","x":[15.651039123535156],"y":[22.31658172607422],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["bran"],"textposition":"bottom center","x":[-18.17171287536621],"y":[9.826386451721191],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["sam"],"textposition":"bottom center","x":[-7.544477939605713],"y":[-25.118675231933594],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["brienne"],"textposition":"bottom center","x":[-19.636924743652344],"y":[-7.047758102416992],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["jorah"],"textposition":"bottom center","x":[-13.778736114501953],"y":[8.08511734008789],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["davos"],"textposition":"bottom center","x":[-13.011062622070312],"y":[0.2628607749938965],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["bronn"],"textposition":"bottom center","x":[-22.425731658935547],"y":[-8.836084365844727],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["dothraki"],"textposition":"bottom center","x":[-7.56638765335083],"y":[0.9370441436767578],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["catelyn"],"textposition":"bottom center","x":[1.5340135097503662],"y":[-20.442689895629883],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["gendry"],"textposition":"bottom center","x":[-12.320427894592285],"y":[-3.2229843139648438],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["robert"],"textposition":"bottom center","x":[26.246803283691406],"y":[-8.62685489654541],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["knight"],"textposition":"bottom center","x":[26.330551147460938],"y":[-18.282806396484375],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["red"],"textposition":"bottom center","x":[-15.776707649230957],"y":[31.451129913330078],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["hodor"],"textposition":"bottom center","x":[-17.303720474243164],"y":[7.867206573486328],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["bolton"],"textposition":"bottom center","x":[6.347208499908447],"y":[-20.475378036499023],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["loras"],"textposition":"bottom center","x":[-24.694969177246094],"y":[23.6126651763916],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["ygritte"],"textposition":"bottom center","x":[-7.659514904022217],"y":[-21.236736297607422],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["euron"],"textposition":"bottom center","x":[-1.231 ...

# %%
nlp("hug")[0].tag_
# Out:
# 'NNP'

# %%
all_characters = []
for s in df[df["Speaker"].notnull()]["Speaker"].unique():
    all_characters.append(s.split()[0].lower())

# %%
all_characters
# Out:
# ['waymar',
#  'will',
#  'gared',
#  'royce',
#  'jon',
#  'septa',
#  'sansa',
#  'septa',
#  'ned',
#  'robb',
#  'jon/robb',
#  'cassel',
#  'catelyn',
#  'will',
#  'will',
#  'jon',
#  'bran',
#  'theon',
#  'robb',
#  'bran',
#  'jaime',
#  'cersei',
#  'maester',
#  'luwin',
#  'bran',
#  'arya',
#  'robert',
#  'arya',
#  'tyrion',
#  'ros',
#  'viserys',
#  'viserys',
#  'daenerys',
#  'maid',
#  'illyrio',
#  'benjen',
#  'tyrion',
#  'sansa',
#  'cersei',
#  'a',
#  'jorah',
#  'khal',
#  'the',
#  'yoren',
#  'arya',
#  'bran',
#  'osha',
#  'rickon',
#  'maester',
#  'several',
#  'catelyn',
#  'robb',
#  'marillion',
#  'joffrey',
#  'sansa',
#  'sandor',
#  'jonos',
#  'galbart',
#  'rickard',
#  'theon',
#  'greatjon',
#  'all',
#  'stark',
#  'jaime',
#  'lancel',
#  'cersei',
#  'tywin',
#  'tyrion',
#  'leo',
#  'addam',
#  'kevan',
#  'daenerys',
#  'jorah',
#  'mirri',
#  'samwell',
#  'jon',
#  'shae',
#  'sam,',
#  'grenn',
#  'pyp',
#  'grand',
#  'ros',
#  'varys',
#  'petyr',
#  'hot',
#  'lommy',
#  'gendry',
#  'jeor',
#  'rakharo',
#  'doreah',
#  'irri',
#  'viserys',
#  'myrcella',
#  'cersei',
#  'eddard',
#  'robert',
#  'benjen',
#  'assassin',
#  'jhiqui',
#  'rodrick',
#  'mycah',
#  'soldier',
#  'soldier',
#  'jory',
#  'soldier',
#  'king’s',
#  'renly',
#  'septa',
#  'old',
#  'guard',
#  'alliser',
#  'rast',
#  'barristan',
#  'rhakaro',
#  'maester',
#  'khal',
#  'syrio',
#  'janos',
#  'hugh',
#  'tobho',
#  'masha',
#  'bronn',
#  'knight',
#  'knight',
#  'loras',
#  'rodrik',
#  'illyrio',
#  'guard',
#  'guard',
#  'vardis',
#  'steward',
#  'lysa',
#  'robin',
#  'mord',
#  'mhaegen',
#  'wildling',
#  'wildling',
#  'jora',
#  'knight',
#  'knight',
#  'knight',
#  'knight',
#  'knight',
#  'ser',
#  'barriston',
#  'man',
#  'beric',
#  'mordane',
#  'ned',
#  'night',
#  'lord',
#  'daenerys',
#  'deanerys',
#  'little',
#  'wine',
#  'samwel',
#  'jaremy',
#  'othell',
#  'pypar',
#  'tell',
#  'tomard',
#  'both',
#  'fellow',
#  'messenger',
#  'varly',
#  'king',
#  'steward',
#  'meryn',
#  'maryn',
#  'kings',
#  'stable',
#  'ser',
#  'nights',
#  'remember',
#  'shagga',
#  'daenarys',
#  'rhakharo',
#  'dothraki',
#  'mago',
#  'qotho',
#  'mago',
#  'brann',
#  'hodor',
#  'jamie',
#  'rodrik',
#  'stark',
#  'lannister',
#  "king's",
#  'everyone',
#  'walder',
#  'stevron',
#  'ryger',
#  'voices',
#  'unidentified',
#  'night’s',
#  'night’s',
#  'cohollo',
#  'prostitute',
#  'lannister',
#  'tribesmen',
#  'stark',
#  'king’s',
#  'street',
#  'populace',
#  'eddark',
#  'joffrey',
#  'announcer',
#  'ser',
#  'bronn',
#  'myrcella',
#  'pycelle',
#  'varys',
#  'baelish',
#  'janos',
#  'cut',
#  'lord',
#  'portan',
#  'osha',
#  'doreah',
#  'rakharo',
#  'sam',
#  'grenn',
#  'edd',
#  'lord',
#  'craster',
#  'watchman',
#  'gilly',
#  'melisandre',
#  'the',
#  'cressen',
#  'davos',
#  'crowd',
#  'stannis',
#  'matthos',
#  'shae',
#  'alton',
#  'ser',
#  'the',
#  'roz',
#  'daisy',
#  'mhaegan',
#  'gold',
#  'blacksmith',
#  'int',
#  'podrick',
#  'cut',
#  'tywin',
#  'littlefinger',
#  'jofffrey',
#  'loras',
#  'margaery',
#  'ext',
#  'brienne',
#  'man',
#  'man',
#  'stannis',
#  'men',
#  'black',
#  'dagmer',
#  'septon',
#  'talisa',
#  'kovarro',
#  'hot',
#  'jaqen',
#  'rickon',
#  'drogo',
#  'pyatt',
#  'ygritte',
#  'rattleshirt',
#  'qhorin',
#  'wildling',
#  'xaro',
#  'eddison',
#  'rorge',
#  'gendry',
#  'yoren',
#  'same',
#  'irri',
#  'woman',
#  'lommy',
#  'yara',
#  'balon',
#  'all',
#  'saan',
#  'jeor',
#  'hodor',
#  'renly',
#  'colen',
#  'gerard',
#  'tommen',
#  'cersel',
#  'priest',
#  'drowned',
#  'timett',
#  'bronn',
#  'amory',
#  'polliver',
#  'armory',
#  'guard',
#  'rennick',
#  'roose',
#  'wounded',
#  'lancel',
#  'meryn',
#  'hound',
#  'man',
#  'man',
#  'soldier',
#  'woman',
#  'mountain',
#  'tickler',
#  'prisoner',
#  "renly's",
#  'spice',
#  'soldier',
#  'soldier',
#  'girl',
#  'protester',
#  'reginald',
#  'haylene',
#  'quaithe',
#  'winterfell',
#  'rodrik',
#  'farlen',
#  'ironborn',
#  'guard',
#  'high',
#  'snsa',
#  'man',
#  'man',
#  'man',
#  'guard',
#  'guard',
#  'cuard',
#  'twyin',
#  'soldier',
#  'soldier',
#  'quent',
#  'catelyin',
#  'ahsa',
#  'danaerys',
#  'rikon',
#  'mountian',
#  'rickard',
#  'child',
#  'handmaiden',
#  'quaith',
#  'silk',
#  'pyat',
#  'jacks',
#  'rickard',
#  'cesei',
#  'mar',
#  'lord',
#  'wildling',
#  'rider',
#  '-robb',
#  'catelyn',
#  'brinenne',
#  'kevan',
#  'quorin',
#  'eddison',
#  'eddision',
#  'whore',
#  'trion',
#  'ayra',
#  'ersei',
#  'prostitute',
#  'gold',
#  'mandon',
#  'all',
#  'another',
#  'male',
#  'boy',
#  'jon',
#  'tormund',
#  'mance',
#  'meryn',
#  'salladhor',
#  'roose',
#  'qyburn',
#  'cut',
#  'kraznys',
#  'missandei',
#  'missandei',
#  'unsullied',
#  'barristan',
#  'man',
#  'frey',
#  'frey',
#  'meera',
#  'jojen',
#  'walder',
#  'ramsay',
#  'frey',
#  'frey',
#  'frey',
#  'maester',
#  'shireen',
#  'cut',
#  'pyp',
#  'barristan',
#  'daughter',
#  'they',
#  'torturer',
#  'tailor',
#  'olenna',
#  'servant',
#  'orell',
#  'rast',
#  'thoros',
#  'anguy',
#  'anguy',
#  'locke',
#  'edmure',
#  'brynden',
#  'driver',
#  'martyn',
#  'woman',
#  'woman',
#  'ramsey',
#  'kraznys',
#  'greizhen',
#  'marei',
#  'woman',
#  'woman',
#  'woman',
#  'woman',
#  'woman',
#  'woman',
#  'karl',
#  'beric',
#  'locke',
#  'locke',
#  'locke',
#  'willem',
#  'selyse',
#  'davis',
#  'cut',
#  'grey',
#  'olyvar',
#  'black',
#  'lothar',
#  'radzal',
#  'qyburn',
#  'myranda',
#  'violet',
#  'steelshanks',
#  'daario',
#  'mero',
#  'prendahl',
#  'baby',
#  'merry',
#  '[scene',
#  'samwell',
#  'pig',
#  'old',
#  'bran',
#  'wildling',
#  'wildling',
#  'orell',
#  'jojen',
#  'tormund',
#  'roslin',
#  'edmure',
#  'daenerys',
#  'blackfish',
#  'everybody',
#  'frey',
#  'man',
#  'man',
#  'dornish',
#  'oberyn',
#  'ellaria',
#  'whore',
#  'whore',
#  'morgan',
#  "morgan's",
#  'denerys',
#  'cersie',
#  'styr',
#  'warg',
#  'officer',
#  'alliser',
#  'janos',
#  'janos',
#  'daaerio',
#  "innkeeper's",
#  'innkeeper',
#  'fennesz',
#  'aemon',
#  'all',
#  'bran',
#  '[jojen',
#  'captain',
#  'ramsay',
#  'tansay',
#  'tansy',
#  'walda',
#  'mace',
#  'axell',
#  'heavy',
#  'three-eyed',
#  'musician',
#  'renly',
#  'robb',
#  'joffrey',
#  'balon',
#  'stannis',
#  'tyron',
#  'farmer',
#  'ranger',
#  'int.',
#  "mole's",
#  "mole's",
#  'olly',
#  'guymon',
#  "olly's",
#  'yarwyck',
#  'dolorous',
#  'alliser',
#  'champion',
#  'daeynerys',
#  'mossador',
#  'elder',
#  'meereen',
#  'great',
#  'slaves',
#  'unsullied',
#  'tanner',
#  'sissy',
#  'women',
#  'int.',
#  'knight',
#  'knight',
#  'knight',
#  'robin',
#  'lysa',
#  'karl',
#  'bron',
#  'locke',
#  'doloroud',
#  'dolrous',
#  'morag',
#  'tycho',
#  'dav',
#  'sallador',
#  'lhara',
#  'first',
#  'bolton',
#  'goatherd',
#  'manservant',
#  'hizdahr',
#  'pyelle',
#  'tyriom',
#  'ytrion',
#  'prisoner',
#  'dying',
#  'alliser',
#  'yarwick',
#  'man',
#  'ed',
#  'dany',
#  'guard',
#  'ralf',
#  'everyone',
#  'man',
#  'petyr',
#  'lord',
#  'lady',
#  'ser',
#  'ser',
#  'ser',
#  'lord',
#  'together',
#  'pycell',
#  'tywen',
#  'thenn',
#  "night's",
#  'member',
#  'donnel',
#  'cooper',
#  'all',
#  'melara',
#  'maggy',
#  'white',
#  'master',
#  'yohn',
#  'squire',
#  'master',
#  'cersei',
#  'grand',
#  'lancel',
#  'kevan',
#  'daario',
#  'hizdahr',
#  'daario',
#  'soldier',
#  'jon',
#  'sam',
#  'sam',
#  'jon',
#  'survivor',
#  'ramsay',
#  'waif',
#  'jaqen',
#  'doran',
#  'tyene',
#  'tyene',
#  'jaime',
#  'myrcella',
#  'jaime',
#  'tyrion',
#  'missandei',
#  'tyrion',
#  'daario',
#  'voice',
#  'septa',
#  'high',
#  'sparrow',
#  'jon',
#  'brother',
#  'braavosi',
#  'waitress',
#  'cut',
#  'knight',
#  'lollys',
#  'lollys',
#  'bronn',
#  'trystane',
#  'areo',
#  'doran',
#  'daario',
#  'barristan',
#  'hunters',
#  'meryn',
#  'mace',
#  'cersei',
#  'gilly',
#  'sam',
#  'gilly',
#  'selyse',
#  'sam',
#  'alliser',
#  'shadow',
#  'janos',
#  'brothers',
#  'harpy',
#  'mossador',
#  'mosador',
#  'hizdahr',
#  'daenerys',
#  'crowd',
#  'daenerys',
#  'daenerys',
#  'title',
#  'bystanders',
#  'margaery',
#  'woman',
#  'priestess',
#  'blonde',
#  'black',
#  'merchant',
#  'militant',
#  'client',
#  'kingsguard',
#  'elaria',
#  'obara',
#  'nymeria',
#  'dario',
#  'allister',
#  'jorah',
#  'malko',
#  'slaver',
#  'malko',
#  'trystane',
#  'bronn',
#  'sand',
#  'bronn',
#  'aemon',
#  'stannis',
#  'derryk',
#  'brand',
#  'sammy',
#  'slave',
#  'buyer',
#  'buer',
#  'olenna',
#  'bronn',
#  'slave',
#  'owner',
#  'owner',
#  'tyrion',
#  'high',
#  'cersei',
#  'arya',
#  'thin',
#  'bolton',
#  'danerys',
#  'master',
#  'karsi',
#  'loboda',
#  'jon',
#  'wildling',
#  'giant',
#  'karsi',
#  'wun',
#  'shouting',
#  'night’s',
#  'myrcella',
#  'thin',
#  'banker',
#  'brothel',
#  'john',
#  'head',
#  'head',
#  'announcer',
#  'quick',
#  'strong',
#  'hizdahr',
#  'jorah',
#  'night’s',
#  'melisandre',
#  'male',
#  'male',
#  'night’s',
#  'night’s',
#  'night’s',
#  'ramsay',
#  'maester',
#  'bolton',
#  'cersei',
#  'septa',
#  'high',
#  'doran',
#  'maester',
#  'tyrion',
#  'varys',
#  'varys',
#  'listeners',
#  'red',
#  'bloodrider',
#  'bloodrider',
#  'bloodrider',
#  'bloodrider',
#  'wife',
#  'wife',
#  'wife#1',
#  'khal',
#  'bloodrider',
#  'khal',
#  'daenerys',
#  'attendant',
#  'mistress',
#  'high',
#  'margaery',
#  'davos',
#  'jon',
#  'lyanna',
#  'vale',
#  'manderly',
#  'glover',
#  'young',
#  'bran',
#  'young',
#  'young',
#  'young',
#  'young',
#  'young',
#  'nan',
#  'three-eyed',
#  'child',
#  'alliser',
#  'storyteller',
#  'king’s',
#  'tyrion',
#  'lord',
#  'lady',
#  'ramsay',
#  'hooded',
#  'euron',
#  'aeron',
#  'davos',
#  'arthur',
#  'bloodrider',
#  'dothraki',
#  'dothraki',
#  'varys',
#  'vala',
#  'tyrion',
#  'little',
#  'qyburns',
#  'cersei',
#  'maester',
#  'cersei',
#  'lady',
#  'kevan',
#  'cersei',
#  'smalljon',
#  'bowen',
#  'othell',
#  'alliser',
#  'man',
#  'man',
#  'littlefinger',
#  'yezzan',
#  'razdal',
#  'belicho',
#  'missandei',
#  'man',
#  'man',
#  'man',
#  'missandei',
#  'darrio',
#  'dothraki',
#  'leader',
#  'lhazareen',
#  'leader',
#  'cersei',
#  'maester',
#  'jaime',
#  'dolorous',
#  'jon',
#  'sansa',
#  'khal',
#  'khal',
#  'khal',
#  'khal',
#  'izembaro',
#  'clarenzo',
#  'ladyc',
#  'camello',
#  'bobono',
#  'lady',
#  'bianca',
#  'izembaro',
#  'bianca',
#  'leaf',
#  'aerson',
#  'daenerys',
#  'man',
#  'kinvara',
#  'rickard',
#  'meera',
#  'hodor',
#  'melessa',
#  'melessa',
#  'talla',
#  'dickon',
#  'melessa',
#  'randyll',
#  'randyll',
#  'izembaro',
#  'bobono',
#  'mace',
#  'rider',
#  'daario',
#  'ray',
#  'sandor',
#  'olenna',
#  'dim',
#  'robett',
#  'lem',
#  'gatins',
#  'young',
#  'young',
#  'red',
#  'lancel',
#  'lancel',
#  'brienne',
#  'grey',
#  'guard',
#  'edmure',
#  'black',
#  'guard',
#  'thoros',
#  'razdal',
#  'grey',
#  'ramsay',
#  'tormund',
#  'tyrion',
#  'tormund',
#  'karstark',
#  'walder',
#  'waldery',
#  'yohn',
#  'ned',
#  'wolkan',
#  'marwyn',
#  'man',
#  'little',
#  'daenerys',
#  'melisdandre',
#  'oleanna',
#  'ellia',
#  'greyworm',
#  'robett',
#  'lyanna',
#  'daerneys',
#  'euron(to',
#  'messenger',
#  'unsullied',
#  'arya(to',
#  'davos(to',
#  'archers',
#  'daenerys(to',
#  'maester',
#  'maester',
#  'guard',
#  'gendry(to',
#  '"robb,',
#  'jon(to',
#  'gendry(to',
#  'harrag',
#  'john',
#  'rhaegar',
#  "bran's",
#  'umber',
#  'man',
#  'gendry',
#  'arya',
#  'harry',
#  'dirah',
#  'crayah',
#  'qyburn',
#  'yara',
#  'dothraki',
#  'jon',
#  'daenerys',
#  'both',
#  'teela',
#  'jon',
#  'jon(v.o.)',
#  'lyanna',
#  'lyann',
#  'podrick',
#  'soldiers',
#  'man',
#  'man',
#  'man',
#  'man',
#  'brinee',
#  'willa',
#  'sarra',
#  'aray',
#  'soldier',
#  'soldier',
#  'soldier',
#  'soldier',
#  'eurion',
#  'a',
#  'jaime',
#  'riverlands',
#  'dornish',
#  'ironborn',
#  'vale',
#  'unsullied']

# %%
import pickle
filename = 'w2v_model.sav'
pickle.dump(w2v_model, open(filename, 'wb'))
