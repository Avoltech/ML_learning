# %%
import re  # For preprocessing
import pandas as pd  # For data handling
from time import time  # To time our operation
from collections import defaultdict  # For word frequency

import spacy  # For preprocessing

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %%
df = pd.read_csv('game-of-thrones.csv')
df.shape
# Out:
# (33198, 5)

# %%
df.head()
# Out:
#                                                 Text       Speaker  \
# 0  [First scene opens with three Rangers riding t...           NaN
# 1   What d’you expect? They’re savages. One lot s...  WAYMAR ROYCE
# 2   I’ve never seen wildlings do a thing like thi...          WILL
# 3                             How close did you get?  WAYMAR ROYCE
# 4                            Close as any man would.          WILL
#
#                Episode     Season             Show
# 0  e1-Winter is Coming  season-01  Game-of-Thrones
# 1  e1-Winter is Coming  season-01  Game-of-Thrones
# 2  e1-Winter is Coming  season-01  Game-of-Thrones
# 3  e1-Winter is Coming  season-01  Game-of-Thrones
# 4  e1-Winter is Coming  season-01  Game-of-Thrones

# %%
nlp = spacy.load('en_core_web_sm') # disabling Named Entity Recognition for speed

def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    txt = [token.lemma_ for token in doc if not token.is_stop]
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    if len(txt) > 2:
        return ' '.join(txt)

# %%
brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df['Text'])

# %%
t = time()

txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_process=-1)]

print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 0.45 mins

# %%
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (24710, 1)

# %%
from gensim.models.phrases import Phrases, Phraser

# %%
sent = [row.split() for row in df_clean['clean']]

# %%
phrases = Phrases(sent, min_count=30, progress_per=10000)
# Out:
# INFO - 19:12:06: collecting all words and their counts
# INFO - 19:12:06: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 19:12:07: PROGRESS: at sentence #10000, processed 66539 words and 50089 word types
# INFO - 19:12:07: PROGRESS: at sentence #20000, processed 141631 words and 93894 word types
# INFO - 19:12:07: collected 113055 token types (unigram + bigrams) from a corpus of 179101 words and 24710 sentences
# INFO - 19:12:07: merged Phrases<113055 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# INFO - 19:12:07: Phrases lifecycle event {'msg': 'built Phrases<113055 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000> in 0.17s', 'datetime': '2023-02-28T19:12:07.102175', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'created'}

# %%
bigram = Phraser(phrases)
sentences = bigram[sent]
# Out:
# INFO - 19:13:52: exporting phrases from Phrases<113055 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# INFO - 19:13:52: FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<54 phrases, min_count=30, threshold=10.0> from Phrases<113055 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000> in 0.16s', 'datetime': '2023-02-28T19:13:52.984477', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'created'}

# %%
sentences
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sentences
#
# NameError: name 'sentences' is not defined

# %%
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 8559

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# ['man', 's', 'look', 'know', 'come', 'want', 'walk', 'king', 'lord', 'tyrion']

# %%
import multiprocessing

from gensim.models import Word2Vec

# %%
cores = multiprocessing.cpu_count() # Count the number of cores in a comput

# %%
cores
# Out:
# 8

# %%
w2v_model = Word2Vec(min_count=20, window=2, vector_size=500, sample=6e-5, alpha=0.03, min_alpha=0.0007, negative=20, workers=cores-1)
# Out:
# INFO - 20:54:05: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=0, vector_size=500, alpha=0.03>', 'datetime': '2023-02-28T20:54:05.521399', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'created'}

# %%
t = time()

w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 20:54:05: collecting all words and their counts
# INFO - 20:54:05: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 20:54:05: PROGRESS: at sentence #10000, processed 65362 words, keeping 5695 word types
# INFO - 20:54:05: PROGRESS: at sentence #20000, processed 138549 words, keeping 7781 word types
# INFO - 20:54:05: collected 8559 word types from a corpus of 175115 raw words and 24710 sentences
# INFO - 20:54:05: Creating a fresh vocabulary
# INFO - 20:54:06: Word2Vec lifecycle event {'msg': 'effective_min_count=20 retains 1440 unique words (16.82% of original 8559, drops 7119)', 'datetime': '2023-02-28T20:54:06.002788', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# INFO - 20:54:06: Word2Vec lifecycle event {'msg': 'effective_min_count=20 leaves 148923 word corpus (85.04% of original 175115, drops 26192)', 'datetime': '2023-02-28T20:54:06.003784', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# INFO - 20:54:06: deleting the raw counts dictionary of 8559 items
# INFO - 20:54:06: sample=6e-05 downsamples 1255 most-common words
# INFO - 20:54:06: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 50220.727777233005 word corpus (33.7%% of prior 148923)', 'datetime': '2023-02-28T20:54:06.022737', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# INFO - 20:54:06: estimated required memory for 1440 words and 500 dimensions: 6480000 bytes
# INFO - 20:54:06: resetting layer weights
# INFO - 20:54:06: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-02-28T20:54:06.045672', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'build_vocab'}
# Time to build vocab: 0.01 mins

# %%
t = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=200, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# WARNING - 20:54:15: Effective 'alpha' higher than previous training cycles
# INFO - 20:54:15: Word2Vec lifecycle event {'msg': 'training model with 7 workers on 1440 vocabulary and 500 features, using sg=0 hs=0 sample=6e-05 negative=20 window=2 shrink_windows=True', 'datetime': '2023-02-28T20:54:15.975195', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'train'}
# INFO - 20:54:16: EPOCH 0: training on 175115 raw words (50024 effective words) took 0.3s, 154962 effective words/s
# INFO - 20:54:16: EPOCH 1: training on 175115 raw words (50285 effective words) took 0.3s, 155327 effective words/s
# INFO - 20:54:17: EPOCH 2: training on 175115 raw words (50250 effective words) took 0.3s, 148487 effective words/s
# INFO - 20:54:17: EPOCH 3: training on 175115 raw words (50284 effective words) took 0.4s, 122414 effective words/s
# INFO - 20:54:18: EPOCH 4: training on 175115 raw words (50005 effective words) took 0.5s, 97940 effective words/s
# INFO - 20:54:18: EPOCH 5: training on 175115 raw words (49918 effective words) took 0.4s, 138967 effective words/s
# INFO - 20:54:18: EPOCH 6: training on 175115 raw words (50138 effective words) took 0.4s, 139526 effective words/s
# INFO - 20:54:19: EPOCH 7: training on 175115 raw words (50390 effective words) took 0.3s, 144814 effective words/s
# INFO - 20:54:19: EPOCH 8: training on 175115 raw words (50252 effective words) took 0.4s, 142708 effective words/s
# INFO - 20:54:19: EPOCH 9: training on 175115 raw words (50477 effective words) took 0.4s, 141716 effective words/s
# INFO - 20:54:20: EPOCH 10: training on 175115 raw words (50102 effective words) took 0.5s, 102052 effective words/s
# INFO - 20:54:20: EPOCH 11: training on 175115 raw words (50306 effective words) took 0.4s, 126154 effective words/s
# INFO - 20:54:21: EPOCH 12: training on 175115 raw words (50087 effective words) took 0.4s, 136196 effective words/s
# INFO - 20:54:21: EPOCH 13: training on 175115 raw words (50130 effective words) took 0.4s, 142937 effective words/s
# INFO - 20:54:21: EPOCH 14: training on 175115 raw words (50264 effective words) took 0.3s, 163474 effective words/s
# INFO - 20:54:22: EPOCH 15: training on 175115 raw words (50148 effective words) took 0.4s, 141921 effective words/s
# INFO - 20:54:22: EPOCH 16: training on 175115 raw words (50407 effective words) took 0.4s, 141759 effective words/s
# INFO - 20:54:23: EPOCH 17: training on 175115 raw words (50248 effective words) took 0.4s, 115464 effective words/s
# INFO - 20:54:23: EPOCH 18: training on 175115 raw words (50381 effective words) took 0.3s, 144965 effective words/s
# INFO - 20:54:23: EPOCH 19: training on 175115 raw words (49979 effective words) took 0.4s, 129552 effective words/s
# INFO - 20:54:24: EPOCH 20: training on 175115 raw words (50481 effective words) took 0.3s, 150702 effective words/s
# INFO - 20:54:24: EPOCH 21: training on 175115 raw words (50291 effective words) took 0.4s, 140052 effective words/s
# INFO - 20:55:31: EPOCH 192: training on 175115 raw words (50078 effective words) took 0.3s, 191850 effective words/s
# INFO - 20:55:31: EPOCH 193: training on 175115 raw words (50081 effective words) took 0.3s, 144994 effective words/s
# INFO - 20:55:32: EPOCH 194: training on 175115 raw words (50185 effective words) took 0.5s, 103514 effective words/s
# INFO - 20:55:32: EPOCH 195: training on 175115 raw words (50376 effective words) took 0.3s, 144810 effective words/s
# INFO - 20:55:32: EPOCH 196: training on 175115 raw words (50061 effective words) took 0.3s, 152741 effective words/s
# INFO - 20:55:33: EPOCH 197: training on 175115 raw words (50198 effective words) took 0.3s, 148502 effective words/s
# INFO - 20:55:33: EPOCH 198: training on 175115 raw words (50315 effective words) took 0.2s, 208647 effective words/s
# INFO - 20:55:33: EPOCH 199: training on 175115 raw words (50182 effective words) took 0.3s, 145004 effective words/s
# INFO - 20:55:33: Word2Vec lifecycle event {'msg': 'training on 35023000 raw words (10042776 effective words) took 77.9s, 128926 effective words/s', 'datetime': '2023-02-28T20:55:33.871933', 'gensim': '4.3.0', 'python': '3.9.7 (tags/v3.9.7:1016ef3, Aug 30 2021, 20:19:38) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'train'}
# Time to train the model: 1.3 mins

# %%
w2v_model.init_sims(replace=True)
# Out:
# C:\Users\abhij\AppData\Local\Temp\ipykernel_14128\514372312.py:1: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   w2v_model.init_sims(replace=True)
# WARNING - 20:56:37: destructive init_sims(replace=True) deprecated & no longer required for space-efficiency

# %%
w2v_model.wv.most_similar(positive=["slave"])
# Out:
# [('master', 0.42362457513809204),
#  ('speak_valyrian', 0.3817283511161804),
#  ('yunkai', 0.373103529214859),
#  ('kraznys', 0.3230419158935547),
#  ('unsullie', 0.3153010904788971),
#  ('meereen', 0.2728897035121918),
#  ('valerian', 0.2709660530090332),
#  ('dragon', 0.2700197100639343),
#  ('dothraki', 0.257055401802063),
#  ('astapor', 0.2508307993412018)]

# %%
w2v_model.sample()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 w2v_model.sample()
#
# TypeError: 'float' object is not callable

# %%
w2v_model.wv.most_similar(positive=['baratheon', 'stark'], negative=['robert'])
# Out:
# [('bolton', 0.297207236289978),
#  ('house', 0.2921888828277588),
#  ('tully', 0.2502659559249878),
#  ('winterfell', 0.24744388461112976),
#  ('banner', 0.24295684695243835),
#  ('pledge', 0.24007676541805267),
#  ('declare', 0.2158336192369461),
#  ('tarth', 0.2122897207736969),
#  ('catelyn', 0.21162854135036469),
#  ('lannister', 0.20848864316940308)]

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
import plotly.express as px
import plotly.graph_objs as go


def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in model.wv.index_to_key:
        tokens.append(model.wv.get_vector(word))
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=3, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(np.array(tokens))

#     fig = px.scatter_3d(
#         new_values, x=0, y=1, z=2,
#         color=df.Speaker, labels={'color': 'species'}
#     )
#     fig.update_traces(marker_size=8)
#     fig.show()

    

    x = []
    y = []

    for value in new_values:
        x.append(value[0])
        y.append(value[1])

    fig = go.Figure()

    for i in range(len(x)):
        fig.add_trace(go.Scatter(x=[x[i]], y=[y[i]],
                        mode='markers+text',
                        text=[labels[i]],
                        textposition='bottom center',
                        marker=dict(size=10)))

    fig.update_layout(
        title="Scatter Plot with Labels",
        xaxis_title="X-axis",
        yaxis_title="Y-axis",
        showlegend=False,
        width=800,
        height=800,
        margin=dict(l=40, r=40, t=80, b=40),
    )

    fig.show()

    
    
#     x = []
#     y = []
#     for value in new_values:
#         x.append(value[0])
#         y.append(value[1])
        
#     plt.figure(figsize=(16, 16)) 
#     for i in range(len(x)):
#         plt.scatter(x[i],y[i])
#         plt.annotate(labels[i],
#                      xy=(x[i], y[i]),
#                      xytext=(5, 2),
#                      textcoords='offset points',
#                      ha='right',
#                      va='bottom')
#     plt.show()

# %%
tsne_plot(w2v_model)
# Out:
# <div>                            <div id="9839b785-ce5f-4506-beea-9bec400934f9" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9839b785-ce5f-4506-beea-9bec400934f9")) {                    Plotly.newPlot(                        "9839b785-ce5f-4506-beea-9bec400934f9",                        [{"marker":{"size":10},"mode":"markers+text","text":["man"],"textposition":"bottom center","x":[-26.095674514770508],"y":[-34.124351501464844],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["s"],"textposition":"bottom center","x":[-29.522769927978516],"y":[-3.259441614151001],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["look"],"textposition":"bottom center","x":[-31.335283279418945],"y":[-3.0208382606506348],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["know"],"textposition":"bottom center","x":[21.729602813720703],"y":[19.645418167114258],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["come"],"textposition":"bottom center","x":[19.643802642822266],"y":[24.37897491455078],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["want"],"textposition":"bottom center","x":[21.572574615478516],"y":[22.422962188720703],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["walk"],"textposition":"bottom center","x":[-27.44068145751953],"y":[-2.244025945663452],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["king"],"textposition":"bottom center","x":[26.472999572753906],"y":[-5.311990261077881],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["lord"],"textposition":"bottom center","x":[24.315349578857422],"y":[5.5971150398254395],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["tyrion"],"textposition":"bottom center","x":[-15.066983222961426],"y":[10.378934860229492],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["jon"],"textposition":"bottom center","x":[-11.0949125289917],"y":[-24.249719619750977],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["like"],"textposition":"bottom center","x":[19.649696350097656],"y":[22.484941482543945],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["stand"],"textposition":"bottom center","x":[-24.01592445373535],"y":[-2.083094835281372],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["hand"],"textposition":"bottom center","x":[-32.49689483642578],"y":[-4.938255786895752],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["think"],"textposition":"bottom center","x":[18.418807983398438],"y":[21.084802627563477],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["tell"],"textposition":"bottom center","x":[27.184946060180664],"y":[14.945394515991211],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["father"],"textposition":"bottom center","x":[21.983570098876953],"y":[3.165437698364258],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["good"],"textposition":"bottom center","x":[16.13121223449707],"y":[23.36989402770996],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["arya"],"textposition":"bottom center","x":[-16.604909896850586],"y":[-1.0357707738876343],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["jaime"],"textposition":"bottom center","x":[-21.687026977539062],"y":[-6.427898406982422],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["kill"],"textposition":"bottom center","x":[18.508821487426758],"y":[1.1919350624084473],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["turn"],"textposition":"bottom center","x":[-31.778553009033203],"y":[ ...

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\abhij\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
fig = go.Figure()

for i in range(len(x)):
    
   # returns a document of object
    doc = nlp(labels[i])

    # checking if it is a noun or not
    if(doc[0].tag_ in ['NNP', 'NNPS']):
        fig.add_trace(go.Scatter(x=[x[i]], y=[y[i]],
                                 mode='markers+text',
                                 text=[labels[i]],
                                 textposition='bottom center',
                                 marker=dict(size=10)))
    else:
        pass
    
   

fig.update_layout(
    title="Scatter Plot with Labels",
    xaxis_title="X-axis",
    yaxis_title="Y-axis",
    showlegend=False,
    width=800,
    height=800,
    margin=dict(l=40, r=40, t=80, b=40),
)

fig.show()
# Out:
# <div>                            <div id="9a6413d2-656b-4a62-b2b5-81e5669786b6" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a6413d2-656b-4a62-b2b5-81e5669786b6")) {                    Plotly.newPlot(                        "9a6413d2-656b-4a62-b2b5-81e5669786b6",                        [{"marker":{"size":10},"mode":"markers+text","text":["lord"],"textposition":"bottom center","x":[24.315349578857422],"y":[5.5971150398254395],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["jon"],"textposition":"bottom center","x":[-11.0949125289917],"y":[-24.249719619750977],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["father"],"textposition":"bottom center","x":[21.983570098876953],"y":[3.165437698364258],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["sansa"],"textposition":"bottom center","x":[-11.103165626525879],"y":[16.97391700744629],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["lady"],"textposition":"bottom center","x":[23.383148193359375],"y":[6.173327922821045],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["boy"],"textposition":"bottom center","x":[15.651039123535156],"y":[22.31658172607422],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["bran"],"textposition":"bottom center","x":[-18.17171287536621],"y":[9.826386451721191],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["sam"],"textposition":"bottom center","x":[-7.544477939605713],"y":[-25.118675231933594],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["brienne"],"textposition":"bottom center","x":[-19.636924743652344],"y":[-7.047758102416992],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["jorah"],"textposition":"bottom center","x":[-13.778736114501953],"y":[8.08511734008789],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["god"],"textposition":"bottom center","x":[33.759700775146484],"y":[7.011960983276367],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["davos"],"textposition":"bottom center","x":[-13.011062622070312],"y":[0.2628607749938965],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["bronn"],"textposition":"bottom center","x":[-22.425731658935547],"y":[-8.836084365844727],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["dothraki"],"textposition":"bottom center","x":[-7.56638765335083],"y":[0.9370441436767578],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["catelyn"],"textposition":"bottom center","x":[1.5340135097503662],"y":[-20.442689895629883],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["gendry"],"textposition":"bottom center","x":[-12.320427894592285],"y":[-3.2229843139648438],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["robert"],"textposition":"bottom center","x":[26.246803283691406],"y":[-8.62685489654541],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["knight"],"textposition":"bottom center","x":[26.330551147460938],"y":[-18.282806396484375],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["red"],"textposition":"bottom center","x":[-15.776707649230957],"y":[31.451129913330078],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["hodor"],"textposition":"bottom center","x":[-17.303720474243164],"y":[7.867206573486328],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["bolton"],"textposition":"bottom center","x":[6.347208499908447],"y":[-20.475378036499023],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["loras"],"textposition":"bottom center","x":[-24.6949691 ...

# %%
sorted(w2v_model.wv.index_to_key)
# Out:
# ["'",
#  'abandon',
#  'able',
#  'accept',
#  'accompany',
#  'act',
#  'actually',
#  'address',
#  'admire',
#  'admit',
#  'advance',
#  'advice',
#  'advise',
#  'aegon',
#  'aemon',
#  'afraid',
#  'age',
#  'ago',
#  'agree',
#  'agreement',
#  'ah',
#  'ahead',
#  'aim',
#  'air',
#  'ale',
#  'alive',
#  'alliance',
#  'alliser',
#  'allow',
#  'ally',
#  'alongside',
#  'andal',
#  'angrily',
#  'angry',
#  'animal',
#  'answer',
#  'anymore',
#  'apart',
#  'apologize',
#  'apology',
#  'appear',
#  'approach',
#  'archer',
#  'archmaester',
#  'aren',
#  'arm',
#  'armor',
#  'army',
#  'arrive',
#  'arrow',
#  'arryn',
#  'arya',
#  'aside',
#  'ask',
#  'ass',
#  'assume',
#  'astapor',
#  'atop',
#  'attack',
#  'attempt',
#  'attention',
#  'audience',
#  'aunt',
#  'avenge',
#  'away',
#  'ax',
#  'axe',
#  'aye',
#  'baby',
#  'back',
#  'background',
#  'bad',
#  'baelish',
#  'baelor',
#  'bag',
#  'balcony',
#  'ball',
#  'balon',
#  'band',
#  'banner',
#  'bannerman',
#  'bar',
#  'baratheon',
#  'bark',
#  'barrel',
#  'barristan',
#  'bastard',
#  'bath',
#  'battle',
#  'battlefield',
#  'bay',
#  'beach',
#  'bear',
#  'beast',
#  'beat',
#  'beautiful',
#  'beauty',
#  'bed',
#  'beg',
#  'begin',
#  'begins',
#  'behead',
#  'believe',
#  'bell',
#  'belly',
#  'belong',
#  'bend',
#  'bend_knee',
#  'beneath',
#  'benjen',
#  'beric',
#  'bet',
#  'betray',
#  'big',
#  'bind',
#  'bird',
#  'birth',
#  'bit',
#  'bitch',
#  'bite',
#  'black',
#  'blackfish',
#  'blackwater',
#  'blade',
#  'blame',
#  'bleed',
#  'bless',
#  'block',
#  'blood',
#  'bloody',
#  'blow',
#  'blue',
#  'boat',
#  'body',
#  'bolt',
#  'bolton',
#  'bone',
#  'book',
#  'boot',
#  'bow',
#  'bowl',
#  'box',
#  'boy',
#  'braavos',
#  'bran',
#  'brandon',
#  'brave',
#  'bread',
#  'break',
#  'breast',
#  'breath',
#  'breathe',
#  'bride',
#  'bridge',
#  'brienne',
#  'bring',
#  'broken',
#  'bronn',
#  'brothel',
#  'brother',
#  'brotherhood',
#  'brynden',
#  'bucket',
#  'build',
#  'builder',
#  'burn',
#  'bury',
#  'business',
#  'busy',
#  'butcher',
#  'buy',
#  'cabin',
#  'cage',
#  'call',
#  'camera',
#  'camera_pan',
#  'camp',
#  'candle',
#  'capital',
#  'captain',
#  'capture',
#  'care',
#  'careful',
#  'carefully',
#  'carriage',
#  'carry',
#  'cart',
#  'carve',
#  'cast',
#  'casterly_rock',
#  'castle',
#  'castle_black',
#  'cat',
#  'catch',
#  'catelyn',
#  'cause',
#  'cave',
#  'cell',
#  'center',
#  'century',
#  'cersei',
#  'certain',
#  'chain',
#  'chair',
#  'chamber',
#  'champion',
#  'chance',
#  'change',
#  'chant',
#  'charge',
#  'chase',
#  'cheek',
#  'cheer',
#  'chest',
#  'child',
#  'choice',
#  'choke',
#  'choose',
#  'chop',
#  'chuckle',
#  'circle',
#  'citadel',
#  'city',
#  'claim',
#  'claw',
#  'clean',
#  'clear',
#  'clegane',
#  'clever',
#  'cliff',
#  'climb',
#  'cloak',
#  'close',
#  'clothe',
#  'cock',
#  'coin',
#  'cold',
#  'collapse',
#  'combat',
#  'come',
#  'command',
#  'commander',
#  'common',
#  'company',
#  'concern',
#  'confess',
#  'conquer',
#  'consider',
#  'continue',
#  'control',
#  'conversation',
#  'convince',
#  'cook',
#  'corner',
#  'corpse',
#  'cost',
#  'cough',
#  'council',
#  'counsel',
#  'count',
#  'country',
#  'courage',
#  'course',
#  'court',
#  'courtyard',
#  'cousin',
#  'cover',
#  'coward',
#  'crack',
#  'craster',
#  'crate',
#  'crawl',
#  'crime',
#  'cripple',
#  'cross',
#  'crossbow',
#  'crow',
#  'crowd',
#  'crown',
#  'cruel',
#  'crush',
#  'cry',
#  'crypt',
#  'cunt',
#  'cup',
#  'curse',
#  'cut',
#  'd',
#  'daario',
#  'daenery',
#  'daenerys',
#  'dagger',
#  'dagmer',
#  'damn',
#  'dance',
#  'dangerous',
#  'dany',
#  'dark',
#  'darkness',
#  'daughter',
#  'davos',
#  'dawn',
#  'day',
#  'dead',
#  'deal',
#  'dear',
#  'death',
#  'debt',
#  'decide',
#  'decision',
#  'deck',
#  'declare',
#  'deep',
#  'deeply',
#  'defeat',
#  'defend',
#  'demand',
#  'deny',
#  'deserve',
#  'desire',
#  'desk',
#  'destroy',
#  'dickon',
#  'didn_t',
#  'die',
#  'difference',
#  'different',
#  'difficult',
#  'direction',
#  'directly',
#  'direwolf',
#  'dirt',
#  'disappear',
#  'discuss',
#  'dismount',
#  'distance',
#  'dock',
#  'doesn_t',
#  'dog',
#  'dolorous_edd',
#  'don_t',
#  'donto',
#  'door',
#  'door_open',
#  'doorway',
#  'doran',
#  'dorne',
#  'dornish',
#  'dothraki',
#  'double',
#  'doubt',
#  'dozen',
#  'drag',
#  'dragon',
#  'dragonglass',
#  'dragonstone',
#  'draw',
#  'draw_sword',
#  'dream',
#  'dress',
#  'drink',
#  'drive',
#  'drogo',
#  'drogon',
#  'drop',
#  'drown',
#  'drunk',
#  'dungeon',
#  'duty',
#  'dwarf',
#  'ear',
#  'early',
#  'east',
#  'easy',
#  'eat',
#  'edd',
#  'eddard',
#  'edge',
#  'edmure',
#  'egg',
#  'eh',
#  'ellaria',
#  'embrace',
#  'emerge',
#  'encampment',
#  'end',
#  'enemy',
#  'engage',
#  'enjoy',
#  'enter',
#  'entire',
#  'entirely',
#  'entrance',
#  'escape',
#  'escort',
#  'euron',
#  'everybody',
#  'evil',
#  'exactly',
#  'exchange',
#  'execute',
#  'exit',
#  'expect',
#  'experience',
#  'explain',
#  'ext',
#  'extend',
#  'eye',
#  'eyed_raven',
#  'eyrie',
#  'face',
#  'fail',
#  'fair',
#  'faith',
#  'faith_militant',
#  'fall',
#  'fall_ground',
#  'family',
#  'fancy',
#  'far',
#  'farmer',
#  'fast',
#  'fat',
#  'fate',
#  'father',
#  'favor',
#  'fear',
#  'feast',
#  'feed',
#  'feel',
#  'fellow',
#  'field',
#  'fight',
#  'fighter',
#  'fighting',
#  'figure',
#  'fill',
#  'final',
#  'finally',
#  'find',
#  'fine',
#  'finger',
#  'finish',
#  'fire',
#  'fish',
#  'fist',
#  'fit',
#  'flame',
#  'flee',
#  'fleet',
#  'flesh',
#  'floor',
#  'flower',
#  'fly',
#  'follow',
#  'food',
#  'fool',
#  'foot',
#  'forbid',
#  'force',
#  'forehead',
#  'foreign',
#  'forest',
#  'forever',
#  'forge',
#  'forget',
#  'forgive',
#  'form',
#  'fortnight',
#  'forward',
#  'free',
#  'free_folk',
#  'freedom',
#  'freeze',
#  'fresh',
#  'frey',
#  'friend',
#  'frighten',
#  'fuck',
#  'fucker',
#  'fucking',
#  'funeral',
#  'funny',
#  'future',
#  'gallop',
#  'game',
#  'garden',
#  'gasp',
#  'gate',
#  'gather',
#  'gaze',
#  'gendry',
#  'gently',
#  'gesture',
#  'get',
#  'ghost',
#  'giant',
#  'gift',
#  'gilly',
#  'girl',
#  'give',
#  'glad',
#  'glance',
#  'glass',
#  'glory',
#  'glover',
#  'go',
#  'go_to',
#  'goat',
#  'god',
#  'godswood',
#  'gold',
#  'gold_cloak',
#  'golden',
#  'good',
#  'grab',
#  'grabs',
#  'grace',
#  'grand_maester',
#  'grandfather',
#  'grandson',
#  'grateful',
#  'great',
#  'green',
#  'greet',
#  'gregor',
#  'grenn',
#  'grey',
#  'grey_worm',
#  'greyjoy',
#  'grip',
#  'groan',
#  'ground',
#  'group',
#  'grow',
#  'growl',
#  'grunt',
#  'guard',
#  'guess',
#  'guest',
#  'guilty',
#  'gut',
#  'hair',
#  'half',
#  'hall',
#  'hallway',
#  'halt',
#  'hammer',
#  'hand',
#  'handmaiden',
#  'handsome',
#  'hang',
#  'happen',
#  'happy',
#  'harbor',
#  'hard',
#  'harm',
#  'harrenhal',
#  'hate',
#  'have',
#  'haven',
#  'head',
#  'hear',
#  'heart',
#  'heavily',
#  'heavy',
#  'heir',
#  'hell',
#  'helmet',
#  'help',
#  'hero',
#  'hesitate',
#  'hide',
#  'high',
#  'high_septon',
#  'high_sparrow',
#  'highgarden',
#  'hill',
#  'history',
#  'hit',
#  'hizdahr',
#  'hmm',
#  'hodor',
#  'hold',
#  'hole',
#  'home',
#  'honest',
#  'honor',
#  'honorable',
#  'hood',
#  'hope',
#  'horde',
#  'horn',
#  'horrible',
#  'horse',
#  'horseback',
#  'hot_pie',
#  'hound',
#  'hour',
#  'house',
#  'howl',
#  'hug',
#  'huh',
#  'hundred',
#  'hungry',
#  'hunt',
#  'hurry',
#  'hurt',
#  'husband',
#  'ice',
#  'idea',
#  'idiot',
#  'imagine',
#  'imp',
#  'important',
#  'include',
#  'innocent',
#  'inside',
#  'inspect',
#  'instead',
#  'insult',
#  'int',
#  'intend',
#  'interest',
#  'interrupt',
#  'invite',
#  'iron',
#  'iron_bank',
#  'iron_island',
#  'iron_throne',
#  'ironborn',
#  'island',
#  'isn_t',
#  'jaime',
#  'jano',
#  'jaqen',
#  'jealous',
#  'jeor',
#  'job',
#  'joffrey',
#  'join',
#  'jojen',
#  'joke',
#  'jon',
#  'jon_snow',
#  'jorah',
#  'judge',
#  'jump',
#  'justice',
#  'karl',
#  'karstark',
#  'keep',
#  'kevan',
#  'khal',
#  'khal_drogo',
#  'khalasar',
#  'khaleesi',
#  'kick',
#  'kill',
#  'killer',
#  'kind',
#  'king',
#  'king_landing',
#  'kingdom',
#  'kingsguard',
#  'kingslayer',
#  'kiss',
#  'kitchen',
#  'knee',
#  'kneel',
#  'knife',
#  'knight',
#  'knock',
#  'know',
#  'kraznys',
#  'l',
#  "l'm",
#  'lad',
#  'lady',
#  'lady_crane',
#  'lancel',
#  'land',
#  'landing',
#  'lannister',
#  'large',
#  'late',
#  'later',
#  'laugh',
#  'law',
#  'lay',
#  'lead',
#  'leader',
#  'leaf',
#  'lean',
#  'learn',
#  'leave',
#  'left',
#  'leg',
#  'lesson',
#  'let',
#  'letter',
#  'liar',
#  'library',
#  'lie',
#  'life',
#  'lift',
#  'light',
#  'like',
#  'line',
#  'lion',
#  'lip',
#  'listen',
#  'little',
#  'littlefinger',
#  'live',
#  'living',
#  'll',
#  'load',
#  'lock',
#  'locke',
#  'long',
#  'longclaw',
#  'look',
#  'loose',
#  'loras',
#  'lord',
#  'lord_commander',
#  'lord_light',
#  'lose',
#  'lot',
#  'love',
#  'lovely',
#  'lover',
#  'low',
#  'lower',
#  'loyal',
#  'loyalty',
#  'lt',
#  'luck',
#  'lucky',
#  'luwin',
#  'lyanna',
#  'lysa',
#  'm',
#  'mace',
#  'mad',
#  'mad_king',
#  'maester',
#  'magic',
#  'main',
#  'make',
#  'man',
#  'manage',
#  'mance',
#  'map',
#  'march',
#  'margaery',
#  'mark',
#  'market',
#  'marriage',
#  'marry',
#  'martell',
#  'marwyn',
#  'master',
#  'match',
#  'matter',
#  'maybe',
#  'mean',
#  'meat',
#  'meera',
#  'meereen',
#  'meet',
#  'meeting',
#  'melisandre',
#  'melt',
#  'member',
#  'memory',
#  'merchant',
#  'mercy',
#  'meryn',
#  'message',
#  'mhysa',
#  'middle',
#  'mile',
#  'mind',
#  'miss',
#  'missandei',
#  'mistake',
#  'moment',
#  'money',
#  'monster',
#  'month',
#  'moon',
#  'mormont',
#  'morning',
#  'mother',
#  'motion',
#  'mount',
#  'mountain',
#  'mouth',
#  'move',
#  'murder',
#  'myranda',
#  'myrcella',
#  'naked',
#  'name',
#  'narrow_sea',
#  'ne',
#  'near',
#  'nearby',
#  'nearly',
#  'neck',
#  'necklace',
#  'ned',
#  'ned_stark',
#  'need',
#  'needle',
#  'nephew',
#  'new',
#  'news',
#  'nice',
#  'night',
#  'night_watch',
#  'noble',
#  'nod',
#  'noise',
#  'north',
#  'northern',
#  'northerner',
#  'nose',
#  'notice',
#  'number',
#  'nymeria',
#  'oath',
#  'oberyn',
#  'obey',
#  'odd',
#  'offer',
#  'oh',
#  'old',
#  'olenna',
#  'olly',
#  'olyvar',
#  'one',
#  'open',
#  'open_door',
#  'opportunity',
#  'opposite',
#  'order',
#  'orell',
#  'osha',
#  'ought',
#  'outside',
#  'overhead',
#  'owe',
#  'oyster',
#  'pace',
#  'pack',
#  'pain',
#  'paint',
#  'pair',
#  'panic',
#  'pant',
#  'paper',
#  'pardon',
#  'party',
#  'pass',
#  'past',
#  'path',
#  'pause',
#  'pay',
#  'payne',
#  'peace',
#  'people',
#  'perfect',
#  'person',
#  'petyr',
#  'pick',
#  'pie',
#  'piece',
#  'pierce',
#  'pig',
#  'pile',
#  'pirate',
#  'piss',
#  'pit',
#  'place',
#  'plan',
#  'platform',
#  'play',
#  'pleased',
#  'pleasure',
#  'pledge',
#  'plenty',
#  'pod',
#  'podrick',
#  'point',
#  'poison',
#  'polliver',
#  'ponder',
#  'poor',
#  'position',
#  'possible',
#  'post',
#  'pot',
#  'pour',
#  'pour_wine',
#  'power',
#  'powerful',
#  'practice',
#  'pray',
#  'prefer',
#  'prepare',
#  'presence',
#  'present',
#  'press',
#  'pretend',
#  'pretty',
#  'price',
#  'pride',
#  'prince',
#  'princess',
#  'prisoner',
#  'probably',
#  'problem',
#  'promise',
#  'prop',
#  'proper',
#  'prostitute',
#  'protect',
#  'protector',
#  'proud',
#  'prove',
#  'provide',
#  'pull',
#  'punch',
#  'punish',
#  'purpose',
#  'push',
#  'put',
#  'pycelle',
#  'pyp',
#  'pyramid',
#  'pyre',
#  'qarth',
#  'qhorin',
#  'quarter',
#  'queen',
#  'question',
#  'quick',
#  'quickly',
#  'quiet',
#  'qyburn',
#  'rabbit',
#  'raid',
#  'rain',
#  'raise',
#  'ramsay',
#  'randyll',
#  'ranger',
#  'rape',
#  'rast',
#  'rat',
#  'raven',
#  'ray',
#  'rayder',
#  'reach',
#  'read',
#  'ready',
#  'real',
#  'realize',
#  'realm',
#  'reason',
#  'rebel',
#  'rebellion',
#  'receive',
#  'recognize',
#  'recruit',
#  'red',
#  'reek',
#  'refuse',
#  'reign',
#  'release',
#  'remain',
#  'remember',
#  'remind',
#  'remove',
#  'renly',
#  'repeatedly',
#  'report',
#  'respect',
#  'respond',
#  'response',
#  'rest',
#  'retrieve',
#  'return',
#  'reveal',
#  'reward',
#  'rhaegal',
#  'rhaegar',
#  ...]

# %%
nlp("tiger")[0].tag_
# Out:
# 'NNS'

# %%
fig = go.Figure()

for i in range(len(x)):
    
   # returns a document of object
    doc = nlp(labels[i].strip())

    # checking if it is a noun or not
    if("sigh" in labels[i]):
        print(labels[i], "<")
        print(doc[0].tag_)
        
    if(doc[0].tag_ in ['NNP']):
        fig.add_trace(go.Scatter(x=[x[i]], y=[y[i]],
                                 mode='markers+text',
                                 text=[labels[i]],
                                 textposition='bottom center',
                                 marker=dict(size=10)))
    else:
        pass
    
   

fig.update_layout(
    title="Scatter Plot with Labels",
    xaxis_title="X-axis",
    yaxis_title="Y-axis",
    showlegend=False,
    width=800,
    height=800,
    margin=dict(l=40, r=40, t=80, b=40),
)

fig.show()
# Out:
# sigh <
# NNP
# sight <
# NN
# <div>                            <div id="22b6d7d9-b220-4a77-b500-c6b8551ba9bc" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22b6d7d9-b220-4a77-b500-c6b8551ba9bc")) {                    Plotly.newPlot(                        "22b6d7d9-b220-4a77-b500-c6b8551ba9bc",                        [{"marker":{"size":10},"mode":"markers+text","text":["lord"],"textposition":"bottom center","x":[24.315349578857422],"y":[5.5971150398254395],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["jon"],"textposition":"bottom center","x":[-11.0949125289917],"y":[-24.249719619750977],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["father"],"textposition":"bottom center","x":[21.983570098876953],"y":[3.165437698364258],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["sansa"],"textposition":"bottom center","x":[-11.103165626525879],"y":[16.97391700744629],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["lady"],"textposition":"bottom center","x":[23.383148193359375],"y":[6.173327922821045],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["boy"],"textposition":"bottom center","x":[15.651039123535156],"y":[22.31658172607422],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["bran"],"textposition":"bottom center","x":[-18.17171287536621],"y":[9.826386451721191],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["sam"],"textposition":"bottom center","x":[-7.544477939605713],"y":[-25.118675231933594],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["brienne"],"textposition":"bottom center","x":[-19.636924743652344],"y":[-7.047758102416992],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["jorah"],"textposition":"bottom center","x":[-13.778736114501953],"y":[8.08511734008789],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["god"],"textposition":"bottom center","x":[33.759700775146484],"y":[7.011960983276367],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["davos"],"textposition":"bottom center","x":[-13.011062622070312],"y":[0.2628607749938965],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["bronn"],"textposition":"bottom center","x":[-22.425731658935547],"y":[-8.836084365844727],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["dothraki"],"textposition":"bottom center","x":[-7.56638765335083],"y":[0.9370441436767578],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["catelyn"],"textposition":"bottom center","x":[1.5340135097503662],"y":[-20.442689895629883],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["gendry"],"textposition":"bottom center","x":[-12.320427894592285],"y":[-3.2229843139648438],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["robert"],"textposition":"bottom center","x":[26.246803283691406],"y":[-8.62685489654541],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["knight"],"textposition":"bottom center","x":[26.330551147460938],"y":[-18.282806396484375],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["red"],"textposition":"bottom center","x":[-15.776707649230957],"y":[31.451129913330078],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["hodor"],"textposition":"bottom center","x":[-17.303720474243164],"y":[7.867206573486328],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["bolton"],"textposition":"bottom center","x":[6.347208499908447],"y":[-20.475378036499023],"type":"scatter"},{"marker":{"size":10},"mode":"markers+text","text":["loras"],"textposition":"bottom center","x":[-24.6949691 ...

# %%
nlp("hug")[0].tag_
# Out:
# 'NNP'

# %%
"sigh <"[:-1].strip()
# Out:
# 'sigh'

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
  
# taking input text as India
text = "India"
ans = nltk.pos_tag()
  
# ans returns a list of tuple
val = ans[0][1]
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\abhij\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[200], line 6
#       4 # taking input text as India
#       5 text = "India"
# ----> 6 ans = nltk.pos_tag(text)
#       8 # ans returns a list of tuple
#       9 val = ans[0][1]
#
# File D:\NLP\lib\site-packages\nltk\tag\__init__.py:166, in pos_tag(tokens, tagset, lang)
#     141 """
#     142 Use NLTK's currently recommended part of speech tagger to
#     143 tag the given list of tokens.
#    (...)
#     163 :rtype: list(tuple(str, str))
#     164 """
#     165 tagger = _get_tagger(lang)
# --> 166 return _pos_tag(tokens, tagset, tagger, lang)
#
# File D:\NLP\lib\site-packages\nltk\tag\__init__.py:120, in _pos_tag(tokens, tagset, tagger, lang)
#     118 # Throws Error if tokens is of string type
#     119 elif isinstance(tokens, str):
# --> 120     raise TypeError("tokens: expected a list of strings, got a string")
#     122 else:
#     123     tagged_tokens = tagger.tag(tokens)
#
# TypeError: tokens: expected a list of strings, got a string
